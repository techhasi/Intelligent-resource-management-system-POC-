# %% [markdown]
# ## **Deep Q-Network for Resource Scaling**
# **A DQN agent is used to decide whether to scale up, scale down, or take no action.**

# %% [markdown]
# 1. Import libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from collections import defaultdict
import time
import pickle
import sys
import math
from datetime import datetime, timedelta
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# 2. Parameters and dataset paths
#
# - Set random seeds for reproducibility. Define Q-learning hyperparameters and file paths

# %%
# Set random seed for reproducibility
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# Enhanced Q-learning parameters
LEARNING_RATE = 0.05
GAMMA = 0.99  # Increased discount factor for more future-oriented decisions
LAMBDA_PARAM = 0.85  # Eligibility trace decay parameter 
EPS_START = 1.0
EPS_END = 0.02  # Slightly higher to maintain some exploration
EPS_DECAY = 0.97  # Slower decay for more thorough exploration
BINS_PER_DIM = 8  # Increased for finer state discretization

# Define paths to dataset files
DATA_FILES = {
    'ec2': '../dataset scripts/ec2_metrics.csv',
    'rds': '../dataset scripts/rds_metrics.csv',
    'ecs': '../dataset scripts/ecs_metrics.csv'
}

# %% [markdown]
# 3. Synthetic data creation
#
# - Generate synthetic EC2, RDS, and ECS data with realistic patterns if data is not available

# %%
# Function to create synthetic data when real data isn't available
def create_synthetic_data():
    """
    Create synthetic data for EC2, RDS, and ECS when the real CSV files are not available.
    """
    print("Creating synthetic data...")
    synthetic_data = {}
    
    # Create a date range for one week with 5-minute intervals
    start_date = datetime(2023, 1, 1)
    end_date = start_date + timedelta(days=7)
    date_range = pd.date_range(start=start_date, end=end_date, freq='5min')
    
    for service in ['ec2', 'rds', 'ecs']:
        # Create a dataframe with timestamp index
        df = pd.DataFrame(index=date_range)
        df.index.name = 'timestamp'
        
        # Add CPU utilization with realistic patterns
        # Base pattern: daily cycle with peak during work hours
        hour_of_day = df.index.hour
        day_of_week = df.index.dayofweek
        
        # Create base CPU pattern (higher during work hours, lower at night)
        base_cpu = 30 + 30 * np.sin(np.pi * (hour_of_day - 6) / 12) * (hour_of_day >= 6) * (hour_of_day <= 18)
        
        # Weekend factor (lower usage on weekends)
        weekend_factor = 0.7 if service == 'ec2' else (0.5 if service == 'rds' else 0.8)
        weekend_mask = (day_of_week >= 5)
        base_cpu[weekend_mask] = base_cpu[weekend_mask] * weekend_factor
        
        # Add some randomness
        noise = np.random.normal(0, 10, size=len(df))
        
        # Add some spikes (to simulate peak loads)
        num_spikes = 10
        spike_idx = np.random.choice(len(df), size=num_spikes, replace=False)
        spike_values = np.random.uniform(20, 50, size=num_spikes)
        spike_contributions = np.zeros(len(df))
        spike_contributions[spike_idx] = spike_values
        
        # Combine all components
        cpu_values = base_cpu + noise + spike_contributions
        
        # Ensure values are within valid range [0, 100]
        cpu_values = np.clip(cpu_values, 0, 100)
        
        # Add to dataframe
        df[f'{service.upper()}_CPUUtilization'] = cpu_values
        
        # Add time features
        df['hour'] = df.index.hour
        df['day_of_week'] = df.index.dayofweek
        
        # Add additional metrics based on service
        if service == 'ec2':
            # Memory utilization correlates with CPU but not perfectly
            df['EC2_MemoryUtilization'] = 0.7 * cpu_values + 0.3 * np.random.normal(50, 10, size=len(df))
            df['EC2_MemoryUtilization'] = np.clip(df['EC2_MemoryUtilization'], 0, 100)
            
            # Network traffic correlates loosely with CPU
            df['EC2_NetworkIn'] = 100 * (0.5 * cpu_values/100 + 0.5 * np.random.exponential(1, size=len(df)))
            df['EC2_NetworkOut'] = 0.7 * df['EC2_NetworkIn'] + 0.3 * np.random.exponential(100, size=len(df))
            
            # Disk operations
            df['EC2_DiskReadOps'] = 50 * (0.3 * cpu_values/100 + 0.7 * np.random.exponential(1, size=len(df)))
            df['EC2_DiskWriteOps'] = 1.5 * df['EC2_DiskReadOps'] + 20 * np.random.exponential(1, size=len(df))
        
        elif service == 'rds':
            # Database metrics
            df['RDS_FreeableMemory'] = 1000 * (1 - 0.7 * cpu_values/100 + 0.3 * np.random.normal(0, 0.1, size=len(df)))
            df['RDS_FreeableMemory'] = np.clip(df['RDS_FreeableMemory'], 100, 1000)
            
            # Database connections
            df['RDS_DatabaseConnections'] = 20 * (0.8 * cpu_values/100 + 0.2 * np.random.exponential(1, size=len(df)))
            
            # Database I/O
            df['RDS_ReadIOPS'] = 100 * (0.6 * cpu_values/100 + 0.4 * np.random.exponential(1, size=len(df)))
            df['RDS_WriteIOPS'] = 0.8 * df['RDS_ReadIOPS'] + 10 * np.random.exponential(1, size=len(df))
        
        elif service == 'ecs':
            # ECS metrics
            df['ECS_MemoryUtilization'] = 0.8 * cpu_values + 0.2 * np.random.normal(60, 15, size=len(df))
            df['ECS_MemoryUtilization'] = np.clip(df['ECS_MemoryUtilization'], 0, 100)
            
            # Task count
            base_tasks = 5 + 15 * (cpu_values / 100)
            df['ECS_RunningTaskCount'] = np.round(base_tasks + np.random.normal(0, 1, size=len(df)))
            df['ECS_RunningTaskCount'] = np.clip(df['ECS_RunningTaskCount'], 1, 50).astype(int)
            
            # Network metrics
            df['ECS_NetworkIn'] = 150 * (0.7 * cpu_values/100 + 0.3 * np.random.exponential(1, size=len(df)))
            df['ECS_NetworkOut'] = 0.6 * df['ECS_NetworkIn'] + 50 * np.random.exponential(1, size=len(df))
        
        # Store dataframe in synthetic data dictionary
        synthetic_data[service] = df
        
        # Save to CSV file
        file_path = DATA_FILES[service]
        directory = os.path.dirname(file_path)
        if directory and not os.path.exists(directory):
            os.makedirs(directory)
            
        df.reset_index().to_csv(file_path, index=False)
        print(f"Created synthetic {service} data with {len(df)} rows, saved to {file_path}")
    
    return synthetic_data

# %% [markdown]
# 3. Load and preprocess data

# %%
def load_data(data_files=DATA_FILES):
    """Load EC2, RDS, and ECS data from CSV files. Create synthetic data if files don't exist."""
    data = {}
    files_missing = False
    
    # Check if any data files are missing
    for service, file_path in data_files.items():
        if not os.path.exists(file_path):
            files_missing = True
            break
    
    # If any files are missing, create synthetic data
    if files_missing:
        data = create_synthetic_data()
    else:
        # Load data from existing files
        for service, file_path in data_files.items():
            try:
                df = pd.read_csv(file_path)
                # Convert timestamp to datetime if it exists
                if 'timestamp' in df.columns:
                    df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')
                    df = df.set_index('timestamp')
                
                # Identify CPU utilization column based on service
                cpu_col = f"{service.upper()}_CPUUtilization"
                if cpu_col in df.columns:
                    # Ensure no NaN values in CPU column
                    df = df.dropna(subset=[cpu_col])
                    
                    # Extract time features if timestamp exists
                    if isinstance(df.index, pd.DatetimeIndex):
                        df['hour'] = df.index.hour
                        df['day_of_week'] = df.index.dayofweek
                    
                    data[service] = df
                    print(f"Loaded {service} data with {len(df)} rows from {file_path}")
                else:
                    print(f"Warning: CPU column {cpu_col} not found in {file_path}")
            except Exception as e:
                print(f"Error loading {file_path}: {e}")
    
    return data

# %% [markdown]
# 4. State Discretization
#
# - Convert continuous state space into discrete bins for Q-learning, handling NaNs safely.

# %%
def safe_discretize_state(state, bins_per_dim=BINS_PER_DIM):
    """
    Discretize the continuous state space with explicit NaN handling.
    Uses finer discretization for more precise state representation.
    
    Args:
        state: The continuous state vector
        bins_per_dim: Number of bins per dimension
        
    Returns:
        Tuple of discrete state indices
    """
    discrete_state = []
    
    try:
        # Resource counts - finer discretization up to 10 instances
        for i in range(3):  # 3 services
            if i < len(state) and not np.isnan(state[i]):
                # Cap at 10 instances, discretize into bins
                resource_count = min(int(state[i]), 10)
                # Map 1-10 to bins_per_dim bins
                bin_idx = min(int((resource_count - 1) * bins_per_dim / 10), bins_per_dim - 1)
                discrete_state.append(bin_idx)
            else:
                # Default value if NaN or out of bounds
                discrete_state.append(1)  # Default to low-mid range
        
        # CPU utilization (normalized to [0,1]) - use finer discretization
        for i in range(3, 9):  # CPU utilization dimensions
            if i < len(state) and not np.isnan(state[i]):
                # Map to bins with finer granularity
                value = max(0.0, min(1.0, state[i]))
                bin_idx = min(int(value * bins_per_dim), bins_per_dim - 1)
                discrete_state.append(bin_idx)
            else:
                # Default to middle bin if NaN or out of bounds
                discrete_state.append(bins_per_dim // 2)
        
        # Add time of day awareness (if available)
        if len(state) > 9 and not np.isnan(state[9]):
            # Hour of day (0-23) discretized into bins
            hour = int(state[9]) % 24
            # Map to periods: night, morning, afternoon, evening
            time_bin = hour // 6
            discrete_state.append(time_bin)
        else:
            # Default to afternoon if not available
            discrete_state.append(2)
        
        # Add day of week awareness (if available)
        if len(state) > 10 and not np.isnan(state[10]):
            # Day of week (0-6) into weekend vs weekday
            day = int(state[10]) % 7
            # 0 for weekday, 1 for weekend
            day_bin = 1 if day >= 5 else 0
            discrete_state.append(day_bin)
        else:
            # Default to weekday if not available
            discrete_state.append(0)
            
    except Exception as e:
        print(f"Error in discretize_state: {e}")
        print(f"Problematic state: {state}")
        # Return a safe default state if any error occurs
        return tuple([1, 1, 1, 2, 2, 2, 2, 2, 2, 2, 0])
    
    return tuple(discrete_state)

# %% [markdown]
# 5. Prioritized Replay Buffer
#
# - Implement a buffer for experience replay with prioritized sampling to improve learning efficiency.

# %%
class PrioritizedReplayBuffer:
    def __init__(self, capacity, alpha=0.6):
        self.capacity = capacity
        self.alpha = alpha  # prioritization exponent
        self.buffer = []
        self.priorities = np.zeros(capacity, dtype=np.float32)
        self.position = 0
        self.size = 0
    
    def push(self, state, action, reward, next_state, done):
        max_priority = np.max(self.priorities) if self.size > 0 else 1.0
        
        if self.size < self.capacity:
            self.buffer.append((state, action, reward, next_state, done))
            self.priorities[self.size] = max_priority
            self.size += 1
        else:
            self.buffer[self.position] = (state, action, reward, next_state, done)
            self.priorities[self.position] = max_priority
        
        self.position = (self.position + 1) % self.capacity
    
    def sample(self, batch_size, beta=0.4):
        if self.size < batch_size:
            return random.sample(self.buffer, self.size), None, None
        
        # Calculate sampling probabilities
        priorities = self.priorities[:self.size]
        probabilities = priorities ** self.alpha
        probabilities /= np.sum(probabilities)
        
        # Sample transitions
        indices = np.random.choice(self.size, batch_size, p=probabilities, replace=False)
        samples = [self.buffer[idx] for idx in indices]
        
        # Calculate importance sampling weights
        weights = (self.size * probabilities[indices]) ** (-beta)
        weights /= np.max(weights)  # Normalize
        
        return samples, indices, weights
    
    def update_priorities(self, indices, priorities):
        for idx, priority in zip(indices, priorities):
            self.priorities[idx] = priority
    
    def __len__(self):
        return self.size

# %% [markdown]
# 6. Enhanced Cloud Environment
#
# - Simulate a cloud environment with dynamic resource allocation and a nuanced reward function.

# %%
# Enhanced Cloud Environment with improved reward function
class EnhancedCloudEnvironment:
    def __init__(self, data, services=['ec2', 'rds', 'ecs']):
        """Initialize the cloud resource environment with workload awareness."""
        self.data = data if data else {}
        self.services = services
        
        # Thresholds for CPU utilization - more sophisticated
        self.cpu_threshold_very_high = 90.0  # Extreme under-provisioning
        self.cpu_threshold_high = 75.0       # High under-provisioning
        self.cpu_threshold_low = 30.0        # Low utilization
        self.cpu_threshold_very_low = 15.0   # Extreme over-provisioning
        self.target_cpu_min = 40.0           # Lower bound of optimal range
        self.target_cpu_max = 65.0           # Upper bound of optimal range
        
        # Service-specific thresholds
        self.service_thresholds = {
            'ec2': {'high': 75.0, 'low': 30.0, 'target_min': 40.0, 'target_max': 65.0},
            'rds': {'high': 70.0, 'low': 25.0, 'target_min': 35.0, 'target_max': 60.0},
            'ecs': {'high': 80.0, 'low': 35.0, 'target_min': 45.0, 'target_max': 70.0}
        }
        
        # Cost factors for different services - more realistic
        self.cost_per_resource = {
            'ec2': 1.0,    # Base EC2 cost
            'rds': 2.5,    # RDS is more expensive
            'ecs': 0.75    # ECS is cheaper
        }
        
        # Scaling costs (penalty for frequent scaling)
        self.scaling_cost = {
            'up': 0.8,     # Reduced startup cost
            'down': 0.3,   # Small shutdown cost
            'none': 0.0    # No change cost
        }
        
        # Scaling history to detect oscillations
        self.scaling_history = {s: [] for s in services}
        
        # Performance reward factors
        self.performance_weight = 4.0  # Increased weight for performance vs cost
        
        # Current state
        self.current_step = 0
        self.max_steps = 100
        
        # Historical metrics for workload patterns
        self.historical_cpu = {s: [] for s in services}
        self.historical_memory = {s: [] for s in services}
        
        # Service-specific attributes for better ECS modeling
        self.ecs_attributes = {
            'memory_to_cpu_ratio': 1.0,  # Default memory-to-CPU ratio
            'task_characteristics': 0.5,  # Normalized task characteristics (0-1)
        }
        
        # Default starting resources and CPU values
        self.reset()
    
    def reset(self):
        """Reset the environment to initial state."""
        self.current_step = 0
        
        # Fixed initial resources
        self.current_resources = {s: 2 for s in self.services}
        
        # Fixed initial CPU values
        self.current_cpu = {s: 50.0 for s in self.services}
        self.current_memory = {s: 50.0 for s in self.services}
        
        # Reset scaling history
        self.scaling_history = {s: [] for s in self.services}
        
        # Reset historical CPU and memory
        self.historical_cpu = {s: [] for s in self.services}
        self.historical_memory = {s: [] for s in self.services}
        
        # If we have data, try to use the first row
        for service in self.services:
            if service in self.data and not self.data[service].empty:
                cpu_col = f"{service.upper()}_CPUUtilization"
                if cpu_col in self.data[service].columns:
                    try:
                        self.current_cpu[service] = self.data[service][cpu_col].iloc[0]
                        # Initialize historical CPU with some data if available
                        if len(self.data[service]) > 10:
                            self.historical_cpu[service] = list(self.data[service][cpu_col].iloc[:10])
                    except Exception:
                        # Keep default if there's any issue
                        pass
                
                # Get memory utilization if available
                memory_col = f"{service.upper()}_MemoryUtilization"
                if memory_col in self.data[service].columns:
                    try:
                        self.current_memory[service] = self.data[service][memory_col].iloc[0]
                        if len(self.data[service]) > 10:
                            self.historical_memory[service] = list(self.data[service][memory_col].iloc[:10])
                    except Exception:
                        # Keep default if there's any issue
                        pass
                
                # Special attributes for ECS
                if service == 'ecs':
                    # Calculate memory-to-CPU ratio for ECS if both metrics are available
                    if len(self.historical_cpu['ecs']) > 0 and len(self.historical_memory['ecs']) > 0:
                        self.ecs_attributes['memory_to_cpu_ratio'] = (
                            np.mean(self.historical_memory['ecs']) / 
                            np.mean(self.historical_cpu['ecs'])
                        )
                    
                    # Get task characteristics if available
                    task_col = "ECS_RunningTaskCount"
                    if task_col in self.data[service].columns:
                        try:
                            # Normalize task count to [0,1]
                            task_count = self.data[service][task_col].iloc[0]
                            self.ecs_attributes['task_characteristics'] = min(task_count / 20.0, 1.0)
                        except Exception:
                            pass
        
        # Get time features if available
        self.current_hour = 12  # Default to noon
        self.current_day = 2    # Default to Wednesday
        
        for service in self.services:
            if service in self.data and not self.data[service].empty:
                if 'hour' in self.data[service].columns and 'day_of_week' in self.data[service].columns:
                    try:
                        self.current_hour = self.data[service]['hour'].iloc[0]
                        self.current_day = self.data[service]['day_of_week'].iloc[0]
                    except Exception:
                        pass
        
        # Update service thresholds based on workload characteristics
        self.update_service_thresholds()
        
        return self.get_state()
    
    def update_service_thresholds(self):
        """Adaptively adjust thresholds based on observed workload patterns"""
        for service in self.services:
            if len(self.historical_cpu[service]) > 20:
                # Calculate statistics from recent history
                recent_cpu = self.historical_cpu[service][-20:]
                mean_cpu = np.mean(recent_cpu)
                std_cpu = np.std(recent_cpu)
                
                # Adjust thresholds based on workload characteristics
                if std_cpu < 5:  # Stable workload
                    # Tighter thresholds for stable workloads
                    self.service_thresholds[service]['target_min'] = max(30, mean_cpu - 10)
                    self.service_thresholds[service]['target_max'] = min(80, mean_cpu + 10)
                else:  # Variable workload
                    # Wider thresholds for variable workloads
                    self.service_thresholds[service]['target_min'] = max(25, mean_cpu - 15)
                    self.service_thresholds[service]['target_max'] = min(85, mean_cpu + 15)
    
    def get_state(self):
        """Get the current state of the environment with time features."""
        try:
            state = []
            
            # Add current resource allocations
            for service in self.services:
                state.append(float(self.current_resources[service]))
            
            # Add current CPU utilization
            for service in self.services:
                state.append(float(self.current_cpu[service]) / 100.0)  # Normalize to [0, 1]
            
            # Add predicted CPU utilization based on recent history
            for service in self.services:
                if len(self.historical_cpu[service]) > 0:
                    # Use exponentially weighted moving average for prediction
                    weights = np.exp(np.linspace(-1, 0, len(self.historical_cpu[service])))
                    weights /= weights.sum()
                    predicted = np.sum(weights * np.array(self.historical_cpu[service]))
                    state.append(float(predicted) / 100.0)  # Normalize to [0, 1]
                else:
                    state.append(float(self.current_cpu[service]) / 100.0)  # Use current as fallback
            
            # Add time features
            state.append(float(self.current_hour))
            state.append(float(self.current_day))
            
            # Add ECS-specific features
            if 'ecs' in self.services:
                # Add memory-to-CPU ratio
                state.append(float(self.ecs_attributes['memory_to_cpu_ratio']))
                # Add task characteristics
                state.append(float(self.ecs_attributes['task_characteristics']))
            
            return np.array(state, dtype=np.float32)
        
        except Exception as e:
            print(f"Error in get_state: {e}")
            # Return a safe default state
            return np.array([2.0, 2.0, 2.0, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 12.0, 2.0], dtype=np.float32)
    
    def step(self, actions):
        """Take a step in the environment with enhanced reward calculation."""
        # Default reward
        total_reward = 0.0
        
        try:
            # Apply actions and calculate reward
            for i, service in enumerate(self.services):
                if i in actions:
                    action = actions[i]
                    old_resources = self.current_resources[service]
                    
                    # Remember previous action for oscillation detection
                    self.scaling_history[service].append(action)
                    if len(self.scaling_history[service]) > 5:
                        self.scaling_history[service].pop(0)
                    
                    # Apply scaling action
                    if action == 0 and self.current_resources[service] > 1:  # Scale down
                        self.current_resources[service] -= 1
                    elif action == 2:  # Scale up
                        self.current_resources[service] += 1
                    # else no change (action == 1)
                    
                    # Update CPU for next step
                    if service in self.data and not self.data[service].empty:
                        cpu_col = f"{service.upper()}_CPUUtilization"
                        if cpu_col in self.data[service].columns:
                            next_step = min(self.current_step + 1, len(self.data[service]) - 1)
                            if next_step >= 0 and next_step < len(self.data[service]):
                                try:
                                    self.current_cpu[service] = self.data[service][cpu_col].iloc[next_step]
                                    
                                    # Update time features if available
                                    if 'hour' in self.data[service].columns and 'day_of_week' in self.data[service].columns:
                                        self.current_hour = self.data[service]['hour'].iloc[next_step]
                                        self.current_day = self.data[service]['day_of_week'].iloc[next_step]
                                        
                                    # Update memory if available
                                    memory_col = f"{service.upper()}_MemoryUtilization"
                                    if memory_col in self.data[service].columns:
                                        self.current_memory[service] = self.data[service][memory_col].iloc[next_step]
                                    
                                    # Update ECS-specific attributes
                                    if service == 'ecs':
                                        task_col = "ECS_RunningTaskCount"
                                        if task_col in self.data[service].columns:
                                            task_count = self.data[service][task_col].iloc[next_step]
                                            self.ecs_attributes['task_characteristics'] = min(task_count / 20.0, 1.0)
                                        
                                        # Update memory-to-CPU ratio
                                        if memory_col in self.data[service].columns:
                                            self.ecs_attributes['memory_to_cpu_ratio'] = (
                                                self.current_memory[service] / max(self.current_cpu[service], 1.0)
                                            )
                                        
                                except Exception:
                                    # Simulate if data access fails
                                    self.current_cpu[service] += random.uniform(-5, 5)
                            else:
                                # Simulate if beyond data length
                                self.current_cpu[service] += random.uniform(-5, 5)
                        else:
                            # Simulate if column not found
                            self.current_cpu[service] += random.uniform(-5, 5)
                    else:
                        # Simulate if no data
                        self.current_cpu[service] += random.uniform(-5, 5)
                    
                    # Ensure CPU is within valid range
                    self.current_cpu[service] = max(0.0, min(100.0, self.current_cpu[service]))
                    
                    # Add to historical CPU
                    self.historical_cpu[service].append(self.current_cpu[service])
                    if len(self.historical_cpu[service]) > 10:
                        self.historical_cpu[service].pop(0)
                    
                    # Add to historical memory if available
                    if service in self.current_memory:
                        self.historical_memory[service].append(self.current_memory[service])
                        if len(self.historical_memory[service]) > 10:
                            self.historical_memory[service].pop(0)
                    
                    # Get service-specific thresholds
                    thresholds = self.service_thresholds.get(service, {
                        'high': self.cpu_threshold_high,
                        'low': self.cpu_threshold_low,
                        'target_min': self.target_cpu_min,
                        'target_max': self.target_cpu_max
                    })
                    
                    # Calculate utilization per resource (safely)
                    if self.current_resources[service] > 0:
                        utilization = self.current_cpu[service] / self.current_resources[service]
                    else:
                        utilization = 100.0  # High utilization if no resources
                    
                    # IMPROVED REWARD FUNCTION - More nuanced with smoother gradients
                    if utilization < self.cpu_threshold_very_low:
                        # Extreme over-provisioning - severe penalty with exponential component
                        over_factor = (self.cpu_threshold_very_low - utilization) / self.cpu_threshold_very_low
                        service_reward = -3.0 - 2.0 * over_factor**2  # Exponential penalty for extreme cases
                    elif utilization < thresholds['low']:
                        # Over-provisioning - smoother gradient
                        low_factor = (utilization - self.cpu_threshold_very_low) / (thresholds['low'] - self.cpu_threshold_very_low)
                        service_reward = -3.0 + 2.5 * low_factor  # Steeper gradient to encourage better utilization
                    elif thresholds['target_min'] <= utilization <= thresholds['target_max']:
                        # Optimal range - gaussian-like reward peak at center
                        center = (thresholds['target_min'] + thresholds['target_max']) / 2
                        distance = abs(utilization - center) / ((thresholds['target_max'] - thresholds['target_min']) / 2)
                        service_reward = 4.0 * (1.0 - distance**2)  # Quadratic reward peaks at center
                    elif utilization < thresholds['high']:
                        # Near optimal but slightly high - small reward
                        high_factor = (thresholds['high'] - utilization) / (thresholds['high'] - thresholds['target_max'])
                        service_reward = 1.0 + 1.5 * high_factor  # Ranges from 1.0 to 2.5
                    elif utilization < self.cpu_threshold_very_high:
                        # Under-provisioning - substantial penalty
                        # Smooth gradient based on distance from high threshold
                        high_factor = (self.cpu_threshold_very_high - utilization) / (self.cpu_threshold_very_high - thresholds['high'])
                        service_reward = -4.0 + 3.0 * high_factor  # Ranges from -4.0 to -1.0
                    else:
                        # Extreme under-provisioning - severe penalty (risk of service degradation)
                        service_reward = -5.0 * (1.0 + (utilization - self.cpu_threshold_very_high) / 10.0)
                    
                    # ECS-specific reward adjustment
                    if service == 'ecs':
                        # Include memory utilization in reward calculation
                        if len(self.historical_memory[service]) > 0:
                            memory_util = self.current_memory[service] / self.current_resources[service]
                            # If memory is a bottleneck, increase penalty
                            if memory_util > 80.0 and utilization < thresholds['high']:
                                service_reward -= 1.5  # Penalty for high memory utilization
                        
                        # Consider task characteristics
                        task_factor = self.ecs_attributes['task_characteristics']
                        # If task characteristics indicate high task density, scale more aggressively
                        if task_factor > 0.7 and utilization > thresholds['target_max']:
                            service_reward -= 1.0  # Additional penalty for high task density
                    
                    # Scaling penalty - proportional to resource count
                    if old_resources != self.current_resources[service]:
                        if action == 0:  # Scale down - small penalty
                            service_reward -= self.scaling_cost['down']
                        elif action == 2:  # Scale up - larger penalty
                            # Quadratic scaling cost based on new resource count
                            service_reward -= self.scaling_cost['up'] * math.sqrt(self.current_resources[service])
                    
                    # Oscillation penalty - strongly discourage rapid up/down cycles
                    if len(self.scaling_history[service]) >= 4:
                        # Check for oscillation patterns
                        last_actions = self.scaling_history[service][-4:]
                        if ((last_actions[0] == 0 and last_actions[2] == 0 and
                             last_actions[1] == 2 and last_actions[3] == 2) or
                            (last_actions[0] == 2 and last_actions[2] == 2 and
                             last_actions[1] == 0 and last_actions[3] == 0)):
                            service_reward -= 4.0  # High penalty for oscillation
                        
                        # Check for overly-frequent changes
                        changes = sum(1 for i in range(len(last_actions) - 1) if last_actions[i] != last_actions[i+1])
                        if changes >= 3:  # Frequent changes
                            service_reward -= 2.0  # Penalty for frequent changes
                    
                    # Cost efficiency component
                    resource_cost = self.cost_per_resource[service] * self.current_resources[service]
                    
                    # Progressive cost penalty - higher for more resources
                    if self.current_resources[service] <= 3:
                        cost_efficiency = -0.3 * resource_cost
                    elif self.current_resources[service] <= 6:
                        cost_efficiency = -0.4 * resource_cost
                    else:
                        cost_efficiency = -0.5 * resource_cost * (1.0 + 0.1 * (self.current_resources[service] - 6))
                    
                    # Balance performance vs cost, favoring performance
                    total_reward += (service_reward * self.performance_weight + cost_efficiency)
            
            # Increment step counter
            self.current_step += 1
            
            # Periodically update service thresholds
            if self.current_step % 20 == 0:
                self.update_service_thresholds()
            
        except Exception as e:
            print(f"Error in step: {e}")
            # Increment step even if there's an error
            self.current_step += 1
        
        # Get the new state
        next_state = self.get_state()
        
        # Check if episode is done
        done = self.current_step >= self.max_steps
        
        # Additional info for debugging
        info = {
            'step': self.current_step,
            'resources': self.current_resources.copy(),
            'current_cpu': self.current_cpu.copy(),
            'hour': self.current_hour,
            'day': self.current_day
        }
        
        return next_state, float(total_reward), done, info

# %% [markdown]
# 7. Q-learning Agent
#
# - Define the Q-learning agent with eligibility traces, prioritized replay, and adaptive strategies.

# %%
class EnhancedQAgent:
    def __init__(self, bins_per_dim=6, action_size_per_service=3, num_services=3):
        """Initialize with simpler state representation and stronger rule-based guidance."""
        self.bins_per_dim = bins_per_dim  # Reduced bins for simpler state space
        self.action_size_per_service = action_size_per_service
        self.num_services = num_services
        
        # Initialize Q-table with a default value of 0
        self.q_table = defaultdict(float)
        
        # Reduced complexity eligibility traces
        self.eligibility_traces = defaultdict(float)
        self.lambda_param = 0.7  # Further reduced for simpler credit assignment
        
        # Start with lower exploration to rely more on rules
        self.epsilon = 0.3  # Start with much lower exploration
        self.epsilon_min = 0.05
        self.epsilon_decay = 0.99
        self.steps_done = 0
        
        # Learning parameters
        self.initial_lr = 0.08
        self.min_lr = 0.01
        
        # Tracking metrics
        self.reward_history = []
        self.epsilon_history = []
        self.loss_history = []
        self.service_states = {i: {} for i in range(num_services)}
        self.action_counts = {i: {0: 0, 1: 0, 2: 0} for i in range(num_services)}
        self.high_cpu_actions = {i: {0: 0, 1: 0, 2: 0} for i in range(num_services)}
        self.service_performance = {i: {'rewards': [], 'actions': []} for i in range(num_services)}
        
        # Service-specific CPU thresholds for better customization
        self.service_thresholds = {
            0: {'low': 15, 'high': 85, 'opt_low': 30, 'opt_high': 70},  # EC2
            1: {'low': 18, 'high': 80, 'opt_low': 35, 'opt_high': 65},  # RDS
            2: {'low': 15, 'high': 85, 'opt_low': 30, 'opt_high': 70}   # ECS
        }
        
        # Initialize Q-table with guided values
        self._initialize_q_table()
        
        # Cache for faster lookups
        self.state_action_cache = {}
    
    def _initialize_q_table(self):
        """Pre-initialize the Q-table with rule-based policy values."""
        print("Initializing Q-table with guided values...")
        # Create a grid of CPU/resource combinations
        for cpu_level in range(0, 101, 5):  # More granular CPU levels: 0, 5, 10, ..., 100
            for resources in range(1, 11):  # Support up to 10 resources
                for service_idx in range(self.num_services):
                    # Get service-specific thresholds
                    thresholds = self.service_thresholds[service_idx]
                    
                    # Create a simplified state representation
                    # We'll use a tuple format that's easier to manage
                    state_key = (resources, cpu_level, service_idx)
                    
                    # Set Q-values based on clear rules
                    if cpu_level >= thresholds['high']:
                        # High CPU - always scale up
                        self.q_table[(state_key, 0)] = -20.0  # Scale down
                        self.q_table[(state_key, 1)] = 0.0    # No change
                        self.q_table[(state_key, 2)] = 20.0   # Scale up
                    elif cpu_level <= thresholds['low'] and resources > 1:
                        # Low CPU with resources to reduce
                        self.q_table[(state_key, 0)] = 10.0   # Scale down
                        self.q_table[(state_key, 1)] = 0.0    # No change
                        self.q_table[(state_key, 2)] = -10.0  # Scale up
                    elif cpu_level <= thresholds['low'] and resources <= 1:
                        # Low CPU but at minimum resources
                        self.q_table[(state_key, 0)] = -15.0  # Scale down (strongly discouraged)
                        self.q_table[(state_key, 1)] = 10.0   # No change (strongly encouraged)
                        self.q_table[(state_key, 2)] = -5.0   # Scale up
                    elif thresholds['opt_low'] <= cpu_level <= thresholds['opt_high']:
                        # Optimal range - maintain resources
                        self.q_table[(state_key, 0)] = -5.0   # Scale down
                        self.q_table[(state_key, 1)] = 10.0   # No change (strongly encouraged)
                        self.q_table[(state_key, 2)] = -5.0   # Scale up
                    elif thresholds['opt_high'] < cpu_level < thresholds['high']:
                        # Approaching high - prepare to scale up
                        self.q_table[(state_key, 0)] = -10.0  # Scale down (strongly discouraged)
                        self.q_table[(state_key, 1)] = 5.0    # No change
                        self.q_table[(state_key, 2)] = 8.0    # Scale up (encouraged)
                    else:  # Between low and opt_low
                        # Approaching low - prepare to scale down if possible
                        if resources > 1:
                            self.q_table[(state_key, 0)] = 8.0    # Scale down (encouraged)
                            self.q_table[(state_key, 1)] = 5.0    # No change
                            self.q_table[(state_key, 2)] = -8.0   # Scale up (discouraged)
                        else:
                            self.q_table[(state_key, 0)] = -10.0  # Scale down (strongly discouraged)
                            self.q_table[(state_key, 1)] = 10.0   # No change (strongly encouraged)
                            self.q_table[(state_key, 2)] = -5.0   # Scale up (discouraged)
        
        print("Q-table initialization complete.")
    
    def get_adaptive_learning_rate(self):
        """Simplified adaptive learning rate function."""
        # Base learning rate decay
        lr = max(self.min_lr, self.initial_lr * (0.99 ** (self.steps_done // 300)))
        
        # Performance-based adjustment - simplified
        if len(self.reward_history) > 10:
            recent_rewards = self.reward_history[-10:]
            if np.mean(recent_rewards[-3:]) > np.mean(recent_rewards[:7]):
                lr *= 1.05  # Increase if improving
            elif np.mean(recent_rewards[-3:]) < np.mean(recent_rewards[:7]):
                lr *= 0.95  # Decrease if getting worse
        
        return np.clip(lr, self.min_lr, self.initial_lr)
    
    def get_simplified_state(self, state, service_idx):
        """Create a simplified state representation focused on key decision factors."""
        try:
            # Get CPU and resources for this service
            if service_idx < len(state) // 2:
                resources = state[service_idx]
                cpu_util = state[service_idx + 3] * 100  # Denormalize
                
                # Simplify to integer values
                resources = int(min(round(resources), 10))  # Cap at 10 resources
                cpu_level = int(min(round(cpu_util), 100))  # Cap at 100%
                
                # Create simplified state key
                return (resources, cpu_level, service_idx)
            else:
                # Default state if service_idx is out of bounds
                return (2, 50, service_idx)
        except Exception as e:
            print(f"Error in get_simplified_state: {e}")
            # Return a safe default
            return (2, 50, service_idx)
    
    def get_q_value(self, state_tuple, service_idx, action):
        """Get Q-value using simplified state representation."""
        key = (state_tuple, action)
        return self.q_table[key]
    
    def set_q_value(self, state_tuple, action, value):
        """Set Q-value using simplified state representation."""
        key = (state_tuple, action)
        self.q_table[key] = float(value)
    
    def select_action(self, state):
        """
        Hybrid action selection with stronger rule-based influence.
        Simplifies state representation and emphasizes threshold-based decisions.
        """
        try:
            # Save a copy of the state for each service
            for i in range(self.num_services):
                service_state = {}
                if i < len(state) // 2:
                    service_state['resources'] = state[i]
                    service_state['cpu'] = state[i + 3] * 100  # Denormalize
                    self.service_states[i] = service_state
            
            # Initialize actions dictionary
            actions = {}
            
            # Determine actions for each service
            for i in range(self.num_services):
                # Get simplified state
                cpu_util = self.service_states[i].get('cpu', 50)
                resources = self.service_states[i].get('resources', 2)
                simple_state = self.get_simplified_state(state, i)
                
                # Get service-specific thresholds
                thresholds = self.service_thresholds[i]
                
                # Apply weighted action selection (rule-based + Q-learning)
                if random.random() > self.epsilon:
                    # Apply strict rule-based policy with high confidence
                    if cpu_util >= thresholds['high']:
                        # Critical high CPU - always scale up
                        actions[i] = 2
                    elif cpu_util <= thresholds['low'] and resources > 1:
                        # Very low CPU with room to scale down
                        actions[i] = 0
                    elif cpu_util <= thresholds['low'] and resources <= 1:
                        # Very low CPU but at minimum resources
                        actions[i] = 1  # No change
                    elif thresholds['opt_low'] <= cpu_util <= thresholds['opt_high']:
                        # Optimal range - always maintain
                        actions[i] = 1
                    else:
                        # For intermediate ranges, use Q-learning but with strong bias
                        # toward rule-based expectations
                        q_values = [self.get_q_value(simple_state, i, a) for a in range(3)]
                        
                        # Add strong biases based on where in the range we are
                        if thresholds['opt_high'] < cpu_util < thresholds['high']:
                            # Between opt_high and high - bias toward scale up
                            q_values[0] -= 5.0  # Penalize scale down
                            q_values[2] += (cpu_util - thresholds['opt_high']) / 10.0  # Proportional boost
                        elif thresholds['low'] < cpu_util < thresholds['opt_low']:
                            # Between low and opt_low - bias toward scale down if resources > 1
                            if resources > 1:
                                q_values[0] += (thresholds['opt_low'] - cpu_util) / 10.0  # Proportional boost
                                q_values[2] -= 5.0  # Penalize scale up
                        
                        # Select best action
                        best_action = np.argmax(q_values)
                        actions[i] = best_action
                else:
                    # Exploration with strong rule bias
                    if cpu_util >= thresholds['high']:
                        # At very high CPU, almost always scale up
                        probs = [0.0, 0.05, 0.95]  # [down, no change, up]
                    elif cpu_util <= thresholds['low'] and resources > 1:
                        # At very low CPU, almost always scale down
                        probs = [0.95, 0.05, 0.0]  # [down, no change, up]
                    elif thresholds['opt_low'] <= cpu_util <= thresholds['opt_high']:
                        # In optimal range, strongly favor no change
                        probs = [0.05, 0.9, 0.05]  # [down, no change, up]
                    elif thresholds['opt_high'] < cpu_util < thresholds['high']:
                        # Between opt_high and high, bias toward scale up
                        scale_factor = (cpu_util - thresholds['opt_high']) / (thresholds['high'] - thresholds['opt_high'])
                        up_prob = 0.3 + 0.6 * scale_factor  # 0.3 to 0.9 based on how close to high threshold
                        probs = [0.0, 1.0 - up_prob, up_prob]  # [down, no change, up]
                    else:  # Between low and opt_low
                        # Between low and opt_low, bias toward scale down if resources > 1
                        if resources > 1:
                            scale_factor = (thresholds['opt_low'] - cpu_util) / (thresholds['opt_low'] - thresholds['low'])
                            down_prob = 0.3 + 0.6 * scale_factor  # 0.3 to 0.9 based on how close to low threshold
                            probs = [down_prob, 1.0 - down_prob, 0.0]  # [down, no change, up]
                        else:
                            # At minimum resources, strongly favor no change
                            probs = [0.0, 0.9, 0.1]  # [down, no change, up]
                    
                    # Safety check for minimum resources
                    if resources <= 1:
                        probs[0] = 0.0  # Never scale below minimum
                        # Redistribute probability
                        total = sum(probs)
                        if total > 0:
                            probs = [p/total for p in probs]
                        else:
                            probs = [0.0, 0.9, 0.1]  # Default to mostly no change
                    
                    # Select action based on probabilities
                    action = random.choices([0, 1, 2], weights=probs)[0]
                    actions[i] = action
                
                # Track actions
                self.action_counts[i][actions[i]] += 1
                if cpu_util > 80:
                    self.high_cpu_actions[i][actions[i]] += 1
            
            return actions
        
        except Exception as e:
            print(f"Error in select_action: {e}")
            print(traceback.format_exc())
            # Default to no change for all services
            return {i: 1 for i in range(self.num_services)}
    
    def update_q_table(self, state, actions, reward, next_state):
        """
        Simplified Q-table update focused on maintaining rule-based policy
        while allowing for minor adaptations in edge cases.
        """
        try:
            # Current learning rate
            learning_rate = self.get_adaptive_learning_rate()
            
            # Make sure reward is valid
            if np.isnan(reward):
                reward = 0.0
            
            # Update Q-values for each service
            for i in range(self.num_services):
                if i in actions:
                    action = actions[i]
                    
                    # Get simplified states
                    simple_state = self.get_simplified_state(state, i)
                    next_simple_state = self.get_simplified_state(next_state, i)
                    
                    # Service-specific adjustments
                    cpu_util = self.service_states[i].get('cpu', 50)
                    resources = self.service_states[i].get('resources', 2)
                    thresholds = self.service_thresholds[i]
                    
                    # Determine if this action aligned with rule-based policy
                    followed_rules = False
                    if cpu_util >= thresholds['high'] and action == 2:
                        # Followed rule: scale up at high CPU
                        followed_rules = True
                    elif cpu_util <= thresholds['low'] and resources > 1 and action == 0:
                        # Followed rule: scale down at low CPU
                        followed_rules = True
                    elif thresholds['opt_low'] <= cpu_util <= thresholds['opt_high'] and action == 1:
                        # Followed rule: no change in optimal range
                        followed_rules = True
                    
                    # Modify reward based on rule adherence
                    effective_reward = reward / self.num_services
                    if followed_rules:
                        # Bonus for following rules
                        effective_reward += 2.0
                    elif (cpu_util >= thresholds['high'] and action == 0) or \
                         (cpu_util <= thresholds['low'] and resources > 1 and action == 2):
                        # Penalty for contradicting clear rules
                        effective_reward -= 5.0
                    
                    # Get current Q-value
                    current_q = self.get_q_value(simple_state, i, action)
                    
                    # Determine best next action
                    next_q_values = [self.get_q_value(next_simple_state, i, a) for a in range(3)]
                    max_next_q = max(next_q_values)
                    
                    # Apply conservative update with clipping
                    td_error = effective_reward + 0.9 * max_next_q - current_q
                    td_error = np.clip(td_error, -5.0, 5.0)  # Prevent large updates
                    
                    # Apply update with momentum (to reduce oscillation)
                    new_q = current_q + learning_rate * td_error
                    
                    # For rule-following states, bias toward keeping rule-based values
                    if followed_rules:
                        # Blend with original rule-based value
                        original_rule_value = self.get_initial_q_value(simple_state, i, action)
                        new_q = 0.7 * original_rule_value + 0.3 * new_q
                    
                    # Ensure valid Q-value
                    if np.isfinite(new_q):
                        self.set_q_value(simple_state, action, new_q)
            
            # Track overall reward
            self.reward_history.append(reward)
        
        except Exception as e:
            print(f"Error in update_q_table: {e}")
            print(traceback.format_exc())
    
    def get_initial_q_value(self, state_tuple, service_idx, action):
        """Get the initial rule-based Q-value for a state-action pair."""
        # Extract state components
        resources, cpu_level, _ = state_tuple
        thresholds = self.service_thresholds[service_idx]
        
        # Return value based on rules
        if cpu_level >= thresholds['high']:
            # High CPU
            return [-20.0, 0.0, 20.0][action]
        elif cpu_level <= thresholds['low'] and resources > 1:
            # Low CPU with resources to reduce
            return [10.0, 0.0, -10.0][action]
        elif cpu_level <= thresholds['low'] and resources <= 1:
            # Low CPU but at minimum resources
            return [-15.0, 10.0, -5.0][action]
        elif thresholds['opt_low'] <= cpu_level <= thresholds['opt_high']:
            # Optimal range
            return [-5.0, 10.0, -5.0][action]
        elif thresholds['opt_high'] < cpu_level < thresholds['high']:
            # Approaching high
            return [-10.0, 5.0, 8.0][action]
        else:  # Between low and opt_low
            if resources > 1:
                return [8.0, 5.0, -8.0][action]
            else:
                return [-10.0, 10.0, -5.0][action]
    
    def update_epsilon(self):
        """Very slow epsilon decay to maintain rule adherence."""
        # Decay much more slowly to maintain rule-based behavior
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
        self.epsilon_history.append(self.epsilon)
        self.steps_done += 1
    
    def save_model(self, file_path):
        """Save the Q-table to disk."""
        try:
            model_data = {
                'q_table': dict(self.q_table),
                'epsilon': self.epsilon,
                'reward_history': self.reward_history,
                'epsilon_history': self.epsilon_history,
                'bins_per_dim': self.bins_per_dim,
                'action_size_per_service': self.action_size_per_service,
                'num_services': self.num_services,
                'loss_history': self.loss_history,
                'action_counts': self.action_counts,
                'high_cpu_actions': self.high_cpu_actions,
                'service_performance': self.service_performance,
                'service_thresholds': self.service_thresholds
            }
            
            with open(file_path, 'wb') as f:
                pickle.dump(model_data, f)
            
            print(f"Model saved to {file_path}")
        except Exception as e:
            print(f"Error saving model: {e}")
            print(traceback.format_exc())
    
    def load_model(self, file_path):
        """Load a Q-table from disk."""
        if os.path.exists(file_path):
            try:
                with open(file_path, 'rb') as f:
                    model_data = pickle.load(f)
                
                self.q_table = defaultdict(float, model_data['q_table'])
                self.epsilon = model_data.get('epsilon', self.epsilon_min)
                self.reward_history = model_data.get('reward_history', [])
                self.epsilon_history = model_data.get('epsilon_history', [])
                self.bins_per_dim = model_data.get('bins_per_dim', self.bins_per_dim)
                self.loss_history = model_data.get('loss_history', [])
                self.action_counts = model_data.get('action_counts', 
                                               {i: {0: 0, 1: 0, 2: 0} for i in range(self.num_services)})
                self.high_cpu_actions = model_data.get('high_cpu_actions', 
                                                  {i: {0: 0, 1: 0, 2: 0} for i in range(self.num_services)})
                self.service_performance = model_data.get('service_performance',
                                                     {i: {'rewards': [], 'actions': []} for i in range(self.num_services)})
                self.service_thresholds = model_data.get('service_thresholds', self.service_thresholds)
                
                print(f"Model loaded from {file_path}")
                return True
            except Exception as e:
                print(f"Error loading model: {e}")
                print(traceback.format_exc())
                return False
        return False

# %% [markdown]
# 8. Training Function

# %%
def train_enhanced_agent(env, agent, num_episodes=50, save_path='enhanced_cloud_q.pkl', save_best=True):
    """Train the agent on the environment with improved strategies."""
    episode_rewards = []
    best_reward = float('-inf')
    best_episode = 0
    
    # For progress tracking
    start_time = time.time()
    
    # For visualization during training
    all_resources = []
    all_cpu = []
    
    for episode in range(num_episodes):
        state = env.reset()
        episode_reward = 0
        steps = 0
        done = False
        
        # Episode resources and CPU tracking
        episode_resources = {service: [] for service in env.services}
        episode_cpu = {service: [] for service in env.services}
        
        # Print progress update before episode
        print(f"\nStarting Episode {episode+1}/{num_episodes}...")
        sys.stdout.flush()  # Force display of progress
        
        while not done:
            # Select action
            actions = agent.select_action(state)
            
            # Track current state
            for i, service in enumerate(env.services):
                episode_resources[service].append(env.current_resources[service])
                episode_cpu[service].append(env.current_cpu[service])
            
            # Take action in environment
            next_state, reward, done, info = env.step(actions)
            
            # Update Q-table
            agent.update_q_table(state, actions, reward, next_state)
            
            # Update state and accumulated reward
            state = next_state
            episode_reward += reward
            steps += 1
            
            # Print progress every 10 steps
            if steps > 0 and steps % 10 == 0:
                print(f"  Step {steps}, Reward so far: {episode_reward:.2f}")
                sys.stdout.flush()  # Force display
        
        # Store episode data for visualization
        all_resources.append(episode_resources)
        all_cpu.append(episode_cpu)
        
        # Update exploration rate
        agent.update_epsilon()
        
        # Record episode reward
        episode_rewards.append(episode_reward)
        agent.reward_history.append(episode_reward)
        
        # Calculate elapsed time
        elapsed_time = time.time() - start_time
        
        # Print end of episode statistics
        print(f"Episode {episode+1}/{num_episodes} completed | Steps: {steps} | "
              f"Reward: {episode_reward:.2f} | Epsilon: {agent.epsilon:.2f} | "
              f"Time: {elapsed_time:.1f}s | Q-table size: {len(agent.q_table)}")
        
        # Save best model
        if save_best and episode_reward > best_reward:
            best_reward = episode_reward
            best_episode = episode + 1
            agent.save_model(save_path.replace('.pkl', '_best.pkl'))
            print(f"New best model saved with reward: {best_reward:.2f}")
        
        # Periodically save model
        if (episode + 1) % 10 == 0:
            agent.save_model(save_path.replace('.pkl', f'_ep{episode+1}.pkl'))
            
            # Visualize progress during training
            if episode > 0 and (episode + 1) % 20 == 0:
                visualize_training_progress(episode_rewards, agent, all_resources, all_cpu, episode)
    
    # Save final model
    agent.save_model(save_path)
    print(f"Final model saved to {save_path}")
    print(f"Best model was from episode {best_episode} with reward {best_reward:.2f}")
    
    # Plot training metrics
    plot_training_metrics(agent, episode_rewards)
    
    return agent, best_episode, best_reward

# %% [markdown]
# 9. Visualization Functions

# %%
# Visualization functions for enhanced training analysis
def visualize_training_progress(episode_rewards, agent, all_resources, all_cpu, current_episode):
    """Visualize progress during long training runs."""
    plt.figure(figsize=(15, 10))
    
    # Plot rewards
    plt.subplot(2, 2, 1)
    plt.plot(episode_rewards, 'b-')
    plt.axvline(x=current_episode, color='r', linestyle='--')
    plt.title('Training Rewards')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.grid(True, alpha=0.3)
    
    # Plot Q-value distribution
    plt.subplot(2, 2, 2)
    q_values = list(agent.q_table.values())
    if q_values:
        plt.hist(q_values, bins=50, alpha=0.7)
        plt.axvline(x=0, color='r', linestyle='--')
        plt.title('Current Q-value Distribution')
        plt.xlabel('Q-value')
        plt.ylabel('Frequency')
        plt.grid(True, alpha=0.3)
    
    # Plot resource utilization for last episode
    plt.subplot(2, 2, 3)
    services = list(all_resources[-1].keys())
    for service in services:
        plt.plot(all_resources[-1][service], label=f'{service} resources')
    plt.title('Resource Allocation (Last Episode)')
    plt.xlabel('Step')
    plt.ylabel('Resource Count')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Plot CPU utilization for last episode
    plt.subplot(2, 2, 4)
    for service in services:
        plt.plot(all_cpu[-1][service], label=f'{service} CPU')
    plt.title('CPU Utilization (Last Episode)')
    plt.xlabel('Step')
    plt.ylabel('CPU (%)')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f'training_progress_ep{current_episode+1}.png')
    plt.close()

# Plot training metrics
def plot_training_metrics(agent, episode_rewards):
    """Plot training metrics to visualize agent's learning progress."""
    plt.figure(figsize=(10, 15))
    
    # Plot rewards
    plt.subplot(3, 1, 1)
    plt.plot(episode_rewards, 'b-', label='Episode Reward')
    plt.title('Episode Rewards')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.grid(True, alpha=0.3)
    
    # Plot smoothed rewards
    if len(episode_rewards) > 5:
        window_size = min(10, len(episode_rewards) // 2)
        smoothed = []
        for i in range(len(episode_rewards)):
            if i < window_size:
                smoothed.append(np.mean(episode_rewards[:i+1]))
            else:
                smoothed.append(np.mean(episode_rewards[i-window_size+1:i+1]))
        plt.plot(smoothed, 'r-', alpha=0.7, label='Smoothed')
        plt.legend()
    
    # Plot epsilon
    plt.subplot(3, 1, 2)
    plt.plot(agent.epsilon_history, 'g-')
    plt.title('Exploration Rate (Epsilon)')
    plt.xlabel('Episode')
    plt.ylabel('Epsilon')
    plt.grid(True, alpha=0.3)
    
    # Plot Q-value distribution
    plt.subplot(3, 1, 3)
    q_values = list(agent.q_table.values())
    if q_values:
        plt.hist(q_values, bins=50, alpha=0.7)
        plt.axvline(x=0, color='r', linestyle='--')
        plt.title('Q-value Distribution')
        plt.xlabel('Q-value')
        plt.ylabel('Frequency')
        plt.grid(True, alpha=0.3)
    else:
        plt.text(0.5, 0.5, 'No Q-values to display', 
                 horizontalalignment='center', verticalalignment='center')
    
    plt.tight_layout()
    plt.savefig('enhanced_q_learning_metrics.png')
    plt.show()

# %% [markdown]
# 10. Rule-Based Strategy
#
# - Define a baseline rule-based approach for resource scaling comparison.

# %%
# Rule-based strategy for comparison
def rule_based_action(current_cpu, current_resources, service_idx, services=['ec2', 'rds', 'ecs']):
    """Enhanced rule-based strategy for resource allocation."""
    service = services[service_idx]
    cpu = current_cpu[service]
    resources = current_resources[service]
    
    # Calculate actual utilization per resource
    utilization = cpu / resources if resources > 0 else 100.0
    
    # Different thresholds for different services
    if service == 'ec2':
        high_threshold = 70
        low_threshold = 30
    elif service == 'rds':
        high_threshold = 65
        low_threshold = 25
    else:  # ecs
        high_threshold = 75
        low_threshold = 35
    
    # More sophisticated decision logic
    if utilization > high_threshold:
        # Scale up more aggressively if utilization is very high
        if utilization > 85:
            return 2  # Scale up
        # Consider history and trend before scaling up
        return 2  # Scale up
    elif utilization < low_threshold and resources > 1:
        # Only scale down if persistently low utilization
        return 0  # Scale down
    else:
        return 1  # No change

# %% [markdown]
# 11. Evaluation function

# %%
# Evaluation function for comparing with rule-based approach
def evaluate_agent(agent, env, num_steps=200, verbose=True):
    """Evaluate trained agent's performance without exploration."""
    state = env.reset()
    total_reward = 0
    resources_history = []
    cpu_history = []
    step_rewards = []
    
    # Store initial state
    resources_history.append({s: env.current_resources[s] for s in env.services})
    cpu_history.append({s: env.current_cpu[s] for s in env.services})
    
    # Temporarily disable exploration
    original_epsilon = agent.epsilon
    agent.epsilon = 0
    
    if verbose:
        print(f"Starting evaluation for {num_steps} steps...")
    
    for step in range(num_steps):
        if verbose and step % 25 == 0:
            print(f"  Step {step}/{num_steps}...")
        
        # Select best action according to policy
        actions = agent.select_action(state)
        
        # Take action
        next_state, reward, done, info = env.step(actions)
        
        # Record results
        total_reward += reward
        step_rewards.append(reward)
        resources_history.append({s: env.current_resources[s] for s in env.services})
        cpu_history.append({s: env.current_cpu[s] for s in env.services})
        
        # Update state
        state = next_state
        
        if done:
            break
    
    # Restore original epsilon
    agent.epsilon = original_epsilon
    
    if verbose:
        print(f"Evaluation complete. Total reward: {total_reward:.2f}")
    
    return total_reward, resources_history, cpu_history, step_rewards

# Evaluate rule-based approach for comparison
def evaluate_rule_based(env, num_steps=200, verbose=True):
    """Evaluate an enhanced rule-based strategy for comparison."""
    state = env.reset()
    total_reward = 0
    resources_history = []
    cpu_history = []
    step_rewards = []
    
    # Store initial state
    resources_history.append({s: env.current_resources[s] for s in env.services})
    cpu_history.append({s: env.current_cpu[s] for s in env.services})
    
    if verbose:
        print(f"Starting rule-based evaluation for {num_steps} steps...")
    
    for step in range(num_steps):
        if verbose and step % 25 == 0:
            print(f"  Step {step}/{num_steps}...")
        
        # Select action using rule-based strategy
        actions = {}
        for i, service in enumerate(env.services):
            actions[i] = rule_based_action(env.current_cpu, env.current_resources, i, env.services)
        
        # Take action
        next_state, reward, done, info = env.step(actions)
        
        # Record results
        total_reward += reward
        step_rewards.append(reward)
        resources_history.append({s: env.current_resources[s] for s in env.services})
        cpu_history.append({s: env.current_cpu[s] for s in env.services})
        
        # Update state
        state = next_state
        
        if done:
            break
    
    if verbose:
        print(f"Rule-based evaluation complete. Total reward: {total_reward:.2f}")
    
    return total_reward, resources_history, cpu_history, step_rewards

# Comprehensive evaluation and comparison
def evaluate_model_performance(agent, env, num_steps=200, verbose=True):
    """
    Evaluate the RL model's performance and compare to a rule-based approach.
    
    Args:
        agent: Trained RL agent
        env: Cloud environment
        num_steps: Number of steps to evaluate
        verbose: Whether to print progress
    
    Returns:
        Dictionary of performance metrics
    """
    print(f"Evaluating model for {num_steps} steps...")
    
    # Evaluate Q-learning model
    ql_reward, ql_resources, ql_cpu, ql_step_rewards = evaluate_agent(
        agent, env, num_steps, verbose=verbose)
    
    # Reset environment for rule-based evaluation
    env.reset()
    
    # Evaluate rule-based model
    rb_reward, rb_resources, rb_cpu, rb_step_rewards = evaluate_rule_based(
        env, num_steps, verbose=verbose)
    
    # Calculate metrics for each service
    metrics = {}
    for i, service in enumerate(env.services):
        # Extract resource allocations
        ql_res = [resources[service] for resources in ql_resources]
        rb_res = [resources[service] for resources in rb_resources]
        
        # Calculate metrics
        min_len = min(len(ql_res), len(rb_res))
        if min_len > 0:
            mae = mean_absolute_error(rb_res[:min_len], ql_res[:min_len])
            mse = mean_squared_error(rb_res[:min_len], ql_res[:min_len])
            rmse = np.sqrt(mse)
            
            # Calculate SMAPE (Symmetric Mean Absolute Percentage Error)
            # Adding small constant to avoid division by zero
            denominator = (np.abs(np.array(rb_res[:min_len])) + np.abs(np.array(ql_res[:min_len])) + 1e-8)
            smape = 100.0 * np.mean(np.abs(np.array(rb_res[:min_len]) - np.array(ql_res[:min_len])) / denominator)
            
            metrics[service] = {
                'mae': mae,
                'mse': mse,
                'rmse': rmse,
                'smape': smape
            }
    
    # Calculate overall metrics
    metrics['overall'] = {
        'q_learning_avg_reward': np.mean(ql_step_rewards) if ql_step_rewards else 0,
        'rule_based_avg_reward': np.mean(rb_step_rewards) if rb_step_rewards else 0,
        'reward_improvement': np.mean(ql_step_rewards) - np.mean(rb_step_rewards) if ql_step_rewards and rb_step_rewards else 0
    }
    
    # Visualize results
    plot_comparative_results(ql_resources, rb_resources, ql_cpu, rb_cpu, metrics, env.services)
    
    return metrics, ql_reward, rb_reward

# %% [markdown]
# 12. Visualization for comparative evaluation

# %%
def plot_comparative_results(ql_resources, rb_resources, ql_cpu, rb_cpu, metrics, services):
    """Plot comparative results between Q-learning and rule-based approaches."""
    num_services = len(services)
    plt.figure(figsize=(15, 5 * (num_services + 1)))
    
    # Plot each service
    for i, service in enumerate(services):
        ax = plt.subplot(num_services + 1, 1, i + 1)
        
        # Extract data
        steps = range(min(len(ql_cpu), len(rb_cpu)))
        cpu_values = [cpu[service] for cpu in ql_cpu[:len(steps)]]
        ql_res = [res[service] for res in ql_resources[:len(steps)]]
        rb_res = [res[service] for res in rb_resources[:len(steps)]]
        
        # Plot CPU utilization
        ax.plot(steps, cpu_values, 'k-', label='CPU Utilization', alpha=0.3)
        ax.set_ylabel('CPU Utilization (%)')
        ax.set_ylim(0, max(max(cpu_values) * 1.1, 100))
        
        # Create twin axis for resources
        ax2 = ax.twinx()
        ax2.plot(steps, ql_res, 'b-', label='Q-Learning Resources', linewidth=2)
        ax2.plot(steps, rb_res, 'r--', label='Rule-Based Resources', alpha=0.7)
        ax2.set_ylabel('Resource Count')
        ax2.set_ylim(0, max(max(ql_res), max(rb_res)) * 1.2)
        
        # Set labels and title
        service_metrics = metrics.get(service, {})
        metrics_text = f"MAE: {service_metrics.get('mae', 'N/A'):.4f}, "
        metrics_text += f"RMSE: {service_metrics.get('rmse', 'N/A'):.4f}, "
        metrics_text += f"SMAPE: {service_metrics.get('smape', 'N/A'):.2f}%"
        
        ax.set_title(f"{service.upper()} - CPU vs Resources - {metrics_text}")
        ax.set_xlabel('Step')
        
        # Add legend
        lines1, labels1 = ax.get_legend_handles_labels()
        lines2, labels2 = ax2.get_legend_handles_labels()
        ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper right')
    
    # Plot rewards comparison
    ax = plt.subplot(num_services + 1, 1, num_services + 1)
    
    if 'overall' in metrics:
        ql_reward = metrics['overall'].get('q_learning_avg_reward', 0)
        rb_reward = metrics['overall'].get('rule_based_avg_reward', 0)
        improvement = metrics['overall'].get('reward_improvement', 0)
        
        ax.bar(['Q-Learning', 'Rule-Based'], [ql_reward, rb_reward], color=['blue', 'red'], alpha=0.7)
        ax.set_ylabel('Average Reward')
        ax.set_title('Average Reward Comparison')
        
        # Add improvement text
        ax.text(0.5, (ql_reward + rb_reward) / 2, f"Improvement: {improvement:.2f}", 
                horizontalalignment='center', verticalalignment='center')
    
    plt.tight_layout()
    plt.savefig('comparative_results.png')
    plt.show()

# Print metrics in a formatted way
def print_metrics(metrics):
    """Print the evaluation metrics in a formatted way."""
    print("\n" + "="*50)
    print("EVALUATION METRICS")
    print("="*50)
    
    # Print service-specific metrics
    for service in ['ec2', 'rds', 'ecs']:
        if service in metrics:
            print(f"\n{service.upper()} Metrics:")
            print(f"  MAE: {metrics[service]['mae']:.4f}")
            print(f"  MSE: {metrics[service]['mse']:.4f}")
            print(f"  RMSE: {metrics[service]['rmse']:.4f}")
            print(f"  SMAPE: {metrics[service]['smape']:.2f}%")
    
    # Print overall metrics
    if 'overall' in metrics:
        print("\nOverall Performance:")
        print(f"  Q-Learning Average Reward: {metrics['overall']['q_learning_avg_reward']:.4f}")
        print(f"  Rule-Based Average Reward: {metrics['overall']['rule_based_avg_reward']:.4f}")
        print(f"  Reward Improvement: {metrics['overall']['reward_improvement']:.4f}")
    
    print("\n" + "="*50)

# %% [markdown]
# 13. Main function

# %%
# Main function to run the entire pipeline
def main():
    """Main function to run the enhanced cloud resource optimization with training and evaluation."""
    # Hardcoded defaults
    episodes = 300   # Number of training episodes
    eval_steps = 200  # Number of evaluation steps
    
    # Load data
    print("\nLoading data...")
    try:
        data = load_data()
    except Exception as e:
        print(f"Error loading data: {e}")
        print("Proceeding with empty data - will use simulated data.")
        data = {}
    
    # Create environment
    print("\nInitializing enhanced environment...")
    env = EnhancedCloudEnvironment(data)
    
    # Training phase
    print("\nInitializing enhanced Q-learning agent for training...")
    agent = EnhancedQAgent(bins_per_dim=BINS_PER_DIM)
    
    print(f"\nTraining enhanced model for {episodes} episodes...")
    trained_agent, best_episode, best_reward = train_enhanced_agent(
        env, agent, num_episodes=episodes, save_path='enhanced_cloud_q.pkl')
    
    # Evaluation phase
    print("\nStarting evaluation phase with the best model...")
    best_model_path = 'enhanced_cloud_q_best.pkl'
    eval_agent = EnhancedQAgent(bins_per_dim=BINS_PER_DIM)
    
    if os.path.exists(best_model_path):
        print(f"\nLoading best model from {best_model_path} for evaluation...")
        if eval_agent.load_model(best_model_path):
            # Evaluate the best model
            metrics, ql_reward, rb_reward = evaluate_model_performance(
                eval_agent, env, num_steps=eval_steps)
            
            # Print metrics
            print_metrics(metrics)
            
            print(f"\nFinal Q-Learning reward: {ql_reward:.2f}")
            print(f"Final Rule-Based reward: {rb_reward:.2f}")
            print(f"Improvement: {ql_reward - rb_reward:.2f}")
        else:
            print(f"Failed to load best model from {best_model_path}. Evaluating final trained model instead...")
            metrics, ql_reward, rb_reward = evaluate_model_performance(
                trained_agent, env, num_steps=eval_steps)
            print_metrics(metrics)
            print(f"\nFinal Q-Learning reward: {ql_reward:.2f}")
            print(f"Final Rule-Based reward: {rb_reward:.2f}")
            print(f"Improvement: {ql_reward - rb_reward:.2f}")
    else:
        print(f"Best model file {best_model_path} not found. Evaluating final trained model instead...")
        metrics, ql_reward, rb_reward = evaluate_model_performance(
            trained_agent, env, num_steps=eval_steps)
        print_metrics(metrics)
        print(f"\nFinal Q-Learning reward: {ql_reward:.2f}")
        print(f"Final Rule-Based reward: {rb_reward:.2f}")
        print(f"Improvement: {ql_reward - rb_reward:.2f}")
    
    print("\nTraining and evaluation complete!")
    print(f"Best model was from episode {best_episode} with reward {best_reward:.2f}")

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print(f"Error in main: {e}")
        import traceback
        traceback.print_exc()
# Out:
# Loading data...
# Loaded ec2 data with 43200 rows from ../dataset scripts/ec2_metrics.csv
# Loaded rds data with 43200 rows from ../dataset scripts/rds_metrics.csv
# Loaded ecs data with 43200 rows from ../dataset scripts/ecs_metrics.csv
#
# Initializing enhanced environment...
#
# Initializing enhanced Q-learning agent for training...
# Initializing Q-table with guided values...
# Q-table initialization complete.
#
# Training enhanced model for 300 episodes...
#
# Starting Episode 1/300...
#   Step 10, Reward so far: -228.96
#   Step 20, Reward so far: -391.25
#   Step 30, Reward so far: -1043.61
#   Step 40, Reward so far: -1739.90
#   Step 50, Reward so far: -2489.91
#   Step 60, Reward so far: -3324.38
#   Step 70, Reward so far: -4387.26
#   Step 80, Reward so far: -5623.29
#   Step 90, Reward so far: -6963.64
#   Step 100, Reward so far: -8375.73
# Episode 1/300 completed | Steps: 100 | Reward: -8375.73 | Epsilon: 0.30 | Time: 0.0s | Q-table size: 2464
# Model saved to enhanced_cloud_q_best.pkl
# New best model saved with reward: -8375.73
#
# Starting Episode 2/300...
#   Step 10, Reward so far: -365.70
#   Step 20, Reward so far: -687.60
#   Step 30, Reward so far: -1113.26
#   Step 40, Reward so far: -1624.62
#   Step 50, Reward so far: -2257.22
#   Step 60, Reward so far: -3050.44
#   Step 70, Reward so far: -3971.17
#   Step 80, Reward so far: -4889.89
#   Step 90, Reward so far: -6002.24
#   Step 100, Reward so far: -7196.41
# Episode 2/300 completed | Steps: 100 | Reward: -7196.41 | Epsilon: 0.29 | Time: 0.1s | Q-table size: 2647
# Model saved to enhanced_cloud_q_best.pkl
# New best model saved with reward: -7196.41
#
# Starting Episode 3/300...
#   Step 10, Reward so far: -271.38
#   Step 20, Reward so far: -511.24
#   Step 30, Reward so far: -1174.63
#   Step 40, Reward so far: -1834.40
#   Step 50, Reward so far: -2555.32
#   Step 60, Reward so far: -3403.10
#   Step 70, Reward so far: -4372.77
#   Step 80, Reward so far: -5488.28
#   Step 90, Reward so far: -6655.14
#   Step 100, Reward so far: -7990.50
# Episode 3/300 completed | Steps: 100 | Reward: -7990.50 | Epsilon: 0.29 | Time: 0.1s | Q-table size: 2734
#
# Starting Episode 4/300...
#   Step 10, Reward so far: -247.07
#   Step 20, Reward so far: -577.06
#   Step 30, Reward so far: -997.14
#   Step 40, Reward so far: -1483.63
#   Step 50, Reward so far: -2136.78
#   Step 60, Reward so far: -2923.10
#   Step 70, Reward so far: -3945.30
#   Step 80, Reward so far: -5023.98
#   Step 90, Reward so far: -6217.71
#   Step 100, Reward so far: -7443.23
# Episode 4/300 completed | Steps: 100 | Reward: -7443.23 | Epsilon: 0.29 | Time: 0.1s | Q-table size: 2818
#
# Starting Episode 5/300...
#   Step 10, Reward so far: -250.14
#   Step 20, Reward so far: -490.18
#   Step 30, Reward so far: -927.09
#   Step 40, Reward so far: -1533.77
#   Step 50, Reward so far: -2279.42
#   Step 60, Reward so far: -3106.06
#   Step 70, Reward so far: -4142.51
#   Step 80, Reward so far: -5381.09
#   Step 90, Reward so far: -6871.35
#   Step 100, Reward so far: -8359.63
# Episode 5/300 completed | Steps: 100 | Reward: -8359.63 | Epsilon: 0.29 | Time: 0.1s | Q-table size: 2887
#
# Starting Episode 6/300...
#   Step 10, Reward so far: -197.79
#   Step 20, Reward so far: -266.71
#   Step 30, Reward so far: -903.63
#   Step 40, Reward so far: -1447.37
#   Step 50, Reward so far: -2114.36
#   Step 60, Reward so far: -2890.46
#   Step 70, Reward so far: -3882.04
#   Step 80, Reward so far: -4978.55
#   Step 90, Reward so far: -6189.05
#   Step 100, Reward so far: -7394.45
# Episode 6/300 completed | Steps: 100 | Reward: -7394.45 | Epsilon: 0.28 | Time: 0.2s | Q-table size: 2890
#
# Starting Episode 7/300...
#   Step 10, Reward so far: -267.11
#   Step 20, Reward so far: -539.79
#   Step 30, Reward so far: -1050.74
#   Step 40, Reward so far: -1620.65
#   Step 50, Reward so far: -2289.96
#   Step 60, Reward so far: -3024.31
#   Step 70, Reward so far: -3880.33
#   Step 80, Reward so far: -4923.47
#   Step 90, Reward so far: -6075.22
#   Step 100, Reward so far: -7341.05
# Episode 7/300 completed | Steps: 100 | Reward: -7341.05 | Epsilon: 0.28 | Time: 0.2s | Q-table size: 2941
#
# Starting Episode 8/300...
#   Step 10, Reward so far: -245.40
#   Step 20, Reward so far: -492.21
#   Step 30, Reward so far: -746.78
#   Step 40, Reward so far: -1208.59
#   Step 50, Reward so far: -1856.17
#   Step 60, Reward so far: -2626.47
#   Step 70, Reward so far: -3564.97
#   Step 80, Reward so far: -4743.62
#   Step 90, Reward so far: -6032.01
#   Step 100, Reward so far: -7266.13
# Episode 8/300 completed | Steps: 100 | Reward: -7266.13 | Epsilon: 0.28 | Time: 0.2s | Q-table size: 2995
#
# Starting Episode 9/300...
#   Step 10, Reward so far: -155.02
#   Step 20, Reward so far: -333.57
#   Step 30, Reward so far: -1026.93
#   Step 40, Reward so far: -1722.99
#   Step 50, Reward so far: -2390.73
#   Step 60, Reward so far: -3202.82
#   Step 70, Reward so far: -4164.78
#   Step 80, Reward so far: -5313.66
#   Step 90, Reward so far: -6605.38
#   Step 100, Reward so far: -8046.00
# Episode 9/300 completed | Steps: 100 | Reward: -8046.00 | Epsilon: 0.27 | Time: 0.2s | Q-table size: 3019
#
# Starting Episode 10/300...
#   Step 10, Reward so far: -188.95
#   Step 20, Reward so far: -478.42
#   Step 30, Reward so far: -948.72
#   Step 40, Reward so far: -1451.14
#   Step 50, Reward so far: -2123.62
#   Step 60, Reward so far: -2889.88
#   Step 70, Reward so far: -3795.28
#   Step 80, Reward so far: -4786.42
#   Step 90, Reward so far: -6018.58
#   Step 100, Reward so far: -7208.59
# Episode 10/300 completed | Steps: 100 | Reward: -7208.59 | Epsilon: 0.27 | Time: 0.3s | Q-table size: 3025
# Model saved to enhanced_cloud_q_ep10.pkl
#
# Starting Episode 11/300...
#   Step 10, Reward so far: -198.32
#   Step 20, Reward so far: -559.51
#   Step 30, Reward so far: -800.68
#   Step 40, Reward so far: -1377.30
#   Step 50, Reward so far: -2007.86
#   Step 60, Reward so far: -2767.66
#   Step 70, Reward so far: -3636.17
#   Step 80, Reward so far: -4690.25
#   Step 90, Reward so far: -5797.32
#   Step 100, Reward so far: -6955.05
# Episode 11/300 completed | Steps: 100 | Reward: -6955.05 | Epsilon: 0.27 | Time: 0.3s | Q-table size: 3052
# Model saved to enhanced_cloud_q_best.pkl
# New best model saved with reward: -6955.05
#
# Starting Episode 12/300...
#   Step 10, Reward so far: -164.45
#   Step 20, Reward so far: -364.09
#   Step 30, Reward so far: -658.98
#   Step 40, Reward so far: -1155.24
#   Step 50, Reward so far: -1741.72
#   Step 60, Reward so far: -2417.31
#   Step 70, Reward so far: -3239.30
#   Step 80, Reward so far: -4162.72
#   Step 90, Reward so far: -5169.76
#   Step 100, Reward so far: -6244.42
# Episode 12/300 completed | Steps: 100 | Reward: -6244.42 | Epsilon: 0.27 | Time: 0.3s | Q-table size: 3055
# Model saved to enhanced_cloud_q_best.pkl
# New best model saved with reward: -6244.42
#
# Starting Episode 13/300...
#   Step 10, Reward so far: -164.03
#   Step 20, Reward so far: -443.84
#   Step 30, Reward so far: -615.23
#   Step 40, Reward so far: -1032.81
#   Step 50, Reward so far: -1656.44
#   Step 60, Reward so far: -2420.44
#   Step 70, Reward so far: -3296.14
#   Step 80, Reward so far: -4394.68
#   Step 90, Reward so far: -5547.22
#   Step 100, Reward so far: -6724.11
# Episode 13/300 completed | Steps: 100 | Reward: -6724.11 | Epsilon: 0.26 | Time: 0.3s | Q-table size: 3076
#
# Starting Episode 14/300...
#   Step 10, Reward so far: -215.07
#   Step 20, Reward so far: -559.57
#   Step 30, Reward so far: -1016.98
#   Step 40, Reward so far: -1653.22
#   Step 50, Reward so far: -2365.85
#   Step 60, Reward so far: -3144.04
#   Step 70, Reward so far: -4116.91
#   Step 80, Reward so far: -5321.95
#   Step 90, Reward so far: -6670.92
#   Step 100, Reward so far: -8038.61
# Episode 14/300 completed | Steps: 100 | Reward: -8038.61 | Epsilon: 0.26 | Time: 0.4s | Q-table size: 3100
#
# Starting Episode 15/300...
#   Step 10, Reward so far: -135.45
#   Step 20, Reward so far: -323.33
#   Step 30, Reward so far: -848.93
#   Step 40, Reward so far: -1423.31
#   Step 50, Reward so far: -2030.64
#   Step 60, Reward so far: -2708.71
#   Step 70, Reward so far: -3655.52
#   Step 80, Reward so far: -4754.40
#   Step 90, Reward so far: -6091.71
#   Step 100, Reward so far: -7570.25
# Episode 15/300 completed | Steps: 100 | Reward: -7570.25 | Epsilon: 0.26 | Time: 0.4s | Q-table size: 3133
#
# Starting Episode 16/300...
#   Step 10, Reward so far: -258.76
#   Step 20, Reward so far: -512.49
#   Step 30, Reward so far: -941.41
#   Step 40, Reward so far: -1497.56
#   Step 50, Reward so far: -2118.05
#   Step 60, Reward so far: -2833.63
#   Step 70, Reward so far: -3806.62
#   Step 80, Reward so far: -4752.41
#   Step 90, Reward so far: -5864.40
#   Step 100, Reward so far: -7089.94
# Episode 16/300 completed | Steps: 100 | Reward: -7089.94 | Epsilon: 0.26 | Time: 0.4s | Q-table size: 3142
#
# Starting Episode 17/300...
#   Step 10, Reward so far: -240.84
#   Step 20, Reward so far: -536.51
#   Step 30, Reward so far: -835.81
#   Step 40, Reward so far: -1374.84
#   Step 50, Reward so far: -2063.05
#   Step 60, Reward so far: -2818.27
#   Step 70, Reward so far: -3778.13
#   Step 80, Reward so far: -4845.19
#   Step 90, Reward so far: -6178.34
#   Step 100, Reward so far: -7533.64
# Episode 17/300 completed | Steps: 100 | Reward: -7533.64 | Epsilon: 0.25 | Time: 0.4s | Q-table size: 3160
#
# Starting Episode 18/300...
#   Step 10, Reward so far: -157.17
#   Step 20, Reward so far: -346.40
#   Step 30, Reward so far: -539.10
#   Step 40, Reward so far: -1022.44
#   Step 50, Reward so far: -1707.54
#   Step 60, Reward so far: -2444.56
#   Step 70, Reward so far: -3397.65
#   Step 80, Reward so far: -4539.79
#   Step 90, Reward so far: -5739.77
#   Step 100, Reward so far: -7051.86
# Episode 18/300 completed | Steps: 100 | Reward: -7051.86 | Epsilon: 0.25 | Time: 0.4s | Q-table size: 3196
#
# Starting Episode 19/300...
#   Step 10, Reward so far: -191.75
#   Step 20, Reward so far: -434.16
#   Step 30, Reward so far: -720.12
#   Step 40, Reward so far: -1150.49
#   Step 50, Reward so far: -1750.08
#   Step 60, Reward so far: -2394.88
#   Step 70, Reward so far: -3262.09
#   Step 80, Reward so far: -4142.80
#   Step 90, Reward so far: -5254.08
#   Step 100, Reward so far: -6428.20
# Episode 19/300 completed | Steps: 100 | Reward: -6428.20 | Epsilon: 0.25 | Time: 0.5s | Q-table size: 3220
#
# Starting Episode 20/300...
#   Step 10, Reward so far: -202.07
#   Step 20, Reward so far: -464.16
#   Step 30, Reward so far: -855.61
#   Step 40, Reward so far: -1397.87
#   Step 50, Reward so far: -1931.37
#   Step 60, Reward so far: -2603.59
#   Step 70, Reward so far: -3398.14
#   Step 80, Reward so far: -4377.54
#   Step 90, Reward so far: -5415.46
#   Step 100, Reward so far: -6557.18
# Episode 20/300 completed | Steps: 100 | Reward: -6557.18 | Epsilon: 0.25 | Time: 0.5s | Q-table size: 3235
# Model saved to enhanced_cloud_q_ep20.pkl
#
# Starting Episode 21/300...
#   Step 10, Reward so far: -172.10
#   Step 20, Reward so far: -462.54
#   Step 30, Reward so far: -724.64
#   Step 40, Reward so far: -1215.77
#   Step 50, Reward so far: -1763.11
#   Step 60, Reward so far: -2456.27
#   Step 70, Reward so far: -3302.74
#   Step 80, Reward so far: -4234.79
#   Step 90, Reward so far: -5409.61
#   Step 100, Reward so far: -6709.65
# Episode 21/300 completed | Steps: 100 | Reward: -6709.65 | Epsilon: 0.24 | Time: 0.9s | Q-table size: 3235
#
# Starting Episode 22/300...
#   Step 10, Reward so far: -107.93
#   Step 20, Reward so far: -433.95
#   Step 30, Reward so far: -941.64
#   Step 40, Reward so far: -1440.41
#   Step 50, Reward so far: -2034.04
#   Step 60, Reward so far: -2667.24
#   Step 70, Reward so far: -3506.85
#   Step 80, Reward so far: -4502.87
#   Step 90, Reward so far: -5702.88
#   Step 100, Reward so far: -6914.75
# Episode 22/300 completed | Steps: 100 | Reward: -6914.75 | Epsilon: 0.24 | Time: 0.9s | Q-table size: 3250
#
# Starting Episode 23/300...
#   Step 10, Reward so far: -197.04
#   Step 20, Reward so far: -455.04
#   Step 30, Reward so far: -710.22
#   Step 40, Reward so far: -1188.18
#   Step 50, Reward so far: -1748.23
#   Step 60, Reward so far: -2373.77
#   Step 70, Reward so far: -3144.36
#   Step 80, Reward so far: -3956.68
#   Step 90, Reward so far: -4911.82
#   Step 100, Reward so far: -5973.73
# Episode 23/300 completed | Steps: 100 | Reward: -5973.73 | Epsilon: 0.24 | Time: 1.0s | Q-table size: 3283
# Model saved to enhanced_cloud_q_best.pkl
# New best model saved with reward: -5973.73
#
# Starting Episode 24/300...
#   Step 10, Reward so far: -215.77
#   Step 20, Reward so far: -547.76
#   Step 30, Reward so far: -869.61
#   Step 40, Reward so far: -1361.14
#   Step 50, Reward so far: -2043.41
#   Step 60, Reward so far: -2695.51
#   Step 70, Reward so far: -3618.95
#   Step 80, Reward so far: -4727.41
#   Step 90, Reward so far: -5946.99
#   Step 100, Reward so far: -7114.31
# Episode 24/300 completed | Steps: 100 | Reward: -7114.31 | Epsilon: 0.24 | Time: 1.0s | Q-table size: 3296
#
# Starting Episode 25/300...
#   Step 10, Reward so far: -107.48
#   Step 20, Reward so far: -421.37
#   Step 30, Reward so far: -940.94
#   Step 40, Reward so far: -1541.01
#   Step 50, Reward so far: -2091.15
#   Step 60, Reward so far: -2745.75
#   Step 70, Reward so far: -3602.64
#   Step 80, Reward so far: -4581.72
#   Step 90, Reward so far: -5775.98
#   Step 100, Reward so far: -6956.40
# Episode 25/300 completed | Steps: 100 | Reward: -6956.40 | Epsilon: 0.23 | Time: 1.0s | Q-table size: 3296
#
# Starting Episode 26/300...
#   Step 10, Reward so far: -146.69
#   Step 20, Reward so far: -293.11
#   Step 30, Reward so far: -691.35
#   Step 40, Reward so far: -1157.33
#   Step 50, Reward so far: -1772.63
#   Step 60, Reward so far: -2461.40
#   Step 70, Reward so far: -3406.77
#   Step 80, Reward so far: -4535.28
#   Step 90, Reward so far: -5741.18
#   Step 100, Reward so far: -7085.36
# Episode 26/300 completed | Steps: 100 | Reward: -7085.36 | Epsilon: 0.23 | Time: 1.0s | Q-table size: 3305
#
# Starting Episode 27/300...
#   Step 10, Reward so far: -197.94
#   Step 20, Reward so far: -527.07
#   Step 30, Reward so far: -1092.31
#   Step 40, Reward so far: -1677.19
#   Step 50, Reward so far: -2374.03
#   Step 60, Reward so far: -3060.11
#   Step 70, Reward so far: -3957.94
#   Step 80, Reward so far: -4919.13
#   Step 90, Reward so far: -6054.16
#   Step 100, Reward so far: -7291.23
# Episode 27/300 completed | Steps: 100 | Reward: -7291.23 | Epsilon: 0.23 | Time: 1.1s | Q-table size: 3305
#
# Starting Episode 28/300...
#   Step 10, Reward so far: -113.67
#   Step 20, Reward so far: -310.79
#   Step 30, Reward so far: -631.58
#   Step 40, Reward so far: -1076.19
#   Step 50, Reward so far: -1684.47
#   Step 60, Reward so far: -2380.53
#   Step 70, Reward so far: -3284.72
#   Step 80, Reward so far: -4422.44
#   Step 90, Reward so far: -5677.82
#   Step 100, Reward so far: -6990.05
# Episode 28/300 completed | Steps: 100 | Reward: -6990.05 | Epsilon: 0.23 | Time: 1.1s | Q-table size: 3308
#
# Starting Episode 29/300...
#   Step 10, Reward so far: -146.69
#   Step 20, Reward so far: -458.17
#   Step 30, Reward so far: -777.72
#   Step 40, Reward so far: -1231.00
#   Step 50, Reward so far: -1788.91
#   Step 60, Reward so far: -2448.24
#   Step 70, Reward so far: -3236.73
#   Step 80, Reward so far: -4129.29
#   Step 90, Reward so far: -5176.55
#   Step 100, Reward so far: -6247.81
# Episode 29/300 completed | Steps: 100 | Reward: -6247.81 | Epsilon: 0.22 | Time: 1.1s | Q-table size: 3311
#
# Starting Episode 30/300...
#   Step 10, Reward so far: -111.77
#   Step 20, Reward so far: -374.58
#   Step 30, Reward so far: -744.64
#   Step 40, Reward so far: -1283.96
#   Step 50, Reward so far: -1860.64
#   Step 60, Reward so far: -2508.61
#   Step 70, Reward so far: -3371.49
#   Step 80, Reward so far: -4424.70
#   Step 90, Reward so far: -5636.82
#   Step 100, Reward so far: -6837.80
# Episode 30/300 completed | Steps: 100 | Reward: -6837.80 | Epsilon: 0.22 | Time: 1.2s | Q-table size: 3326
# Model saved to enhanced_cloud_q_ep30.pkl
#
# Starting Episode 31/300...
#   Step 10, Reward so far: -171.15
#   Step 20, Reward so far: -325.36
#   Step 30, Reward so far: -800.27
#   Step 40, Reward so far: -1361.48
#   Step 50, Reward so far: -1933.61
#   Step 60, Reward so far: -2647.29
#   Step 70, Reward so far: -3572.09
#   Step 80, Reward so far: -4628.27
#   Step 90, Reward so far: -5825.12
#   Step 100, Reward so far: -7223.66
# Episode 31/300 completed | Steps: 100 | Reward: -7223.66 | Epsilon: 0.22 | Time: 1.2s | Q-table size: 3329
#
# Starting Episode 32/300...
#   Step 10, Reward so far: -175.70
#   Step 20, Reward so far: -293.99
#   Step 30, Reward so far: -602.43
#   Step 40, Reward so far: -1017.50
#   Step 50, Reward so far: -1584.78
#   Step 60, Reward so far: -2214.28
#   Step 70, Reward so far: -3035.58
#   Step 80, Reward so far: -3994.95
#   Step 90, Reward so far: -5069.78
#   Step 100, Reward so far: -6295.94
# Episode 32/300 completed | Steps: 100 | Reward: -6295.94 | Epsilon: 0.22 | Time: 1.2s | Q-table size: 3332
#
# Starting Episode 33/300...
#   Step 10, Reward so far: -127.00
#   Step 20, Reward so far: -359.05
#   Step 30, Reward so far: -687.82
#   Step 40, Reward so far: -1223.61
#   Step 50, Reward so far: -1848.03
#   Step 60, Reward so far: -2573.49
#   Step 70, Reward so far: -3488.57
#   Step 80, Reward so far: -4416.96
#   Step 90, Reward so far: -5569.15
#   Step 100, Reward so far: -6737.63
# Episode 33/300 completed | Steps: 100 | Reward: -6737.63 | Epsilon: 0.22 | Time: 1.2s | Q-table size: 3332
#
# Starting Episode 34/300...
#   Step 10, Reward so far: -202.23
#   Step 20, Reward so far: -639.58
#   Step 30, Reward so far: -1329.14
#   Step 40, Reward so far: -2011.73
#   Step 50, Reward so far: -2834.51
#   Step 60, Reward so far: -3625.17
#   Step 70, Reward so far: -4753.79
#   Step 80, Reward so far: -5997.74
#   Step 90, Reward so far: -7408.09
#   Step 100, Reward so far: -8931.70
# Episode 34/300 completed | Steps: 100 | Reward: -8931.70 | Epsilon: 0.21 | Time: 1.2s | Q-table size: 3362
#
# Starting Episode 35/300...
#   Step 10, Reward so far: -162.25
#   Step 20, Reward so far: -337.66
#   Step 30, Reward so far: -537.78
#   Step 40, Reward so far: -1013.06
#   Step 50, Reward so far: -1655.08
#   Step 60, Reward so far: -2312.22
#   Step 70, Reward so far: -3126.20
#   Step 80, Reward so far: -4029.57
#   Step 90, Reward so far: -5109.50
#   Step 100, Reward so far: -6191.34
# Episode 35/300 completed | Steps: 100 | Reward: -6191.34 | Epsilon: 0.21 | Time: 1.3s | Q-table size: 3362
#
# Starting Episode 36/300...
#   Step 10, Reward so far: -140.35
#   Step 20, Reward so far: -255.44
#   Step 30, Reward so far: -559.90
#   Step 40, Reward so far: -961.11
#   Step 50, Reward so far: -1495.89
#   Step 60, Reward so far: -2115.55
#   Step 70, Reward so far: -2818.63
#   Step 80, Reward so far: -3730.22
#   Step 90, Reward so far: -4839.93
#   Step 100, Reward so far: -5968.12
# Episode 36/300 completed | Steps: 100 | Reward: -5968.12 | Epsilon: 0.21 | Time: 1.3s | Q-table size: 3362
# Model saved to enhanced_cloud_q_best.pkl
# New best model saved with reward: -5968.12
#
# Starting Episode 37/300...
#   Step 10, Reward so far: -80.13
#   Step 20, Reward so far: -233.59
#   Step 30, Reward so far: -534.86
#   Step 40, Reward so far: -1003.40
#   Step 50, Reward so far: -1723.36
#   Step 60, Reward so far: -2310.67
#   Step 70, Reward so far: -3077.33
#   Step 80, Reward so far: -3981.38
#   Step 90, Reward so far: -5146.63
#   Step 100, Reward so far: -6345.23
# Episode 37/300 completed | Steps: 100 | Reward: -6345.23 | Epsilon: 0.21 | Time: 1.3s | Q-table size: 3362
#
# Starting Episode 38/300...
#   Step 10, Reward so far: -75.65
#   Step 20, Reward so far: -465.00
#   Step 30, Reward so far: -1011.94
#   Step 40, Reward so far: -1534.55
#   Step 50, Reward so far: -2218.20
#   Step 60, Reward so far: -2844.04
#   Step 70, Reward so far: -3629.12
#   Step 80, Reward so far: -4613.74
#   Step 90, Reward so far: -5820.87
#   Step 100, Reward so far: -7068.68
# Episode 38/300 completed | Steps: 100 | Reward: -7068.68 | Epsilon: 0.20 | Time: 1.3s | Q-table size: 3362
#
# Starting Episode 39/300...
#   Step 10, Reward so far: -161.42
#   Step 20, Reward so far: -234.69
#   Step 30, Reward so far: -778.19
#   Step 40, Reward so far: -1352.30
#   Step 50, Reward so far: -2086.21
#   Step 60, Reward so far: -2796.61
#   Step 70, Reward so far: -3632.63
#   Step 80, Reward so far: -4608.90
#   Step 90, Reward so far: -5679.38
#   Step 100, Reward so far: -6793.19
# Episode 39/300 completed | Steps: 100 | Reward: -6793.19 | Epsilon: 0.20 | Time: 1.4s | Q-table size: 3371
#
# Starting Episode 40/300...
#   Step 10, Reward so far: -153.95
#   Step 20, Reward so far: -268.36
#   Step 30, Reward so far: -611.34
#   Step 40, Reward so far: -1157.67
#   Step 50, Reward so far: -1778.73
#   Step 60, Reward so far: -2508.72
#   Step 70, Reward so far: -3300.74
#   Step 80, Reward so far: -4216.60
#   Step 90, Reward so far: -5418.77
#   Step 100, Reward so far: -6789.95
# Episode 40/300 completed | Steps: 100 | Reward: -6789.95 | Epsilon: 0.20 | Time: 1.4s | Q-table size: 3371
# Model saved to enhanced_cloud_q_ep40.pkl
#
# Starting Episode 41/300...
#   Step 10, Reward so far: -146.29
#   Step 20, Reward so far: -220.01
#   Step 30, Reward so far: -456.78
#   Step 40, Reward so far: -904.87
#   Step 50, Reward so far: -1437.65
#   Step 60, Reward so far: -2084.13
#   Step 70, Reward so far: -2943.05
#   Step 80, Reward so far: -3867.05
#   Step 90, Reward so far: -4930.35
#   Step 100, Reward so far: -6048.87
# Episode 41/300 completed | Steps: 100 | Reward: -6048.87 | Epsilon: 0.20 | Time: 1.8s | Q-table size: 3371
#
# Starting Episode 42/300...
#   Step 10, Reward so far: -126.43
#   Step 20, Reward so far: -240.84
#   Step 30, Reward so far: -566.59
#   Step 40, Reward so far: -1101.30
#   Step 50, Reward so far: -1696.98
#   Step 60, Reward so far: -2293.25
#   Step 70, Reward so far: -3090.54
#   Step 80, Reward so far: -4065.21
#   Step 90, Reward so far: -5219.49
#   Step 100, Reward so far: -6398.86
# Episode 42/300 completed | Steps: 100 | Reward: -6398.86 | Epsilon: 0.20 | Time: 1.8s | Q-table size: 3377
#
# Starting Episode 43/300...
#   Step 10, Reward so far: -83.65
#   Step 20, Reward so far: -292.14
#   Step 30, Reward so far: -517.85
#   Step 40, Reward so far: -963.45
#   Step 50, Reward so far: -1561.10
#   Step 60, Reward so far: -2183.88
#   Step 70, Reward so far: -3018.21
#   Step 80, Reward so far: -3983.10
#   Step 90, Reward so far: -5158.49
#   Step 100, Reward so far: -6346.06
# Episode 43/300 completed | Steps: 100 | Reward: -6346.06 | Epsilon: 0.19 | Time: 1.8s | Q-table size: 3380
#
# Starting Episode 44/300...
#   Step 10, Reward so far: -133.46
#   Step 20, Reward so far: -246.37
#   Step 30, Reward so far: -520.80
#   Step 40, Reward so far: -936.61
#   Step 50, Reward so far: -1593.08
#   Step 60, Reward so far: -2197.64
#   Step 70, Reward so far: -2948.75
#   Step 80, Reward so far: -3924.63
#   Step 90, Reward so far: -5062.45
#   Step 100, Reward so far: -6203.29
# Episode 44/300 completed | Steps: 100 | Reward: -6203.29 | Epsilon: 0.19 | Time: 1.8s | Q-table size: 3422
#
# Starting Episode 45/300...
#   Step 10, Reward so far: -140.43
#   Step 20, Reward so far: -273.85
#   Step 30, Reward so far: -493.34
#   Step 40, Reward so far: -1026.26
#   Step 50, Reward so far: -1583.15
#   Step 60, Reward so far: -2210.67
#   Step 70, Reward so far: -2951.74
#   Step 80, Reward so far: -3825.04
#   Step 90, Reward so far: -4894.57
#   Step 100, Reward so far: -5983.31
# Episode 45/300 completed | Steps: 100 | Reward: -5983.31 | Epsilon: 0.19 | Time: 1.9s | Q-table size: 3422
#
# Starting Episode 46/300...
#   Step 10, Reward so far: -113.15
#   Step 20, Reward so far: -242.60
#   Step 30, Reward so far: -740.09
#   Step 40, Reward so far: -1191.20
#   Step 50, Reward so far: -1758.97
#   Step 60, Reward so far: -2450.01
#   Step 70, Reward so far: -3292.27
#   Step 80, Reward so far: -4289.41
#   Step 90, Reward so far: -5410.97
#   Step 100, Reward so far: -6530.69
# Episode 46/300 completed | Steps: 100 | Reward: -6530.69 | Epsilon: 0.19 | Time: 1.9s | Q-table size: 3422
#
# Starting Episode 47/300...
#   Step 10, Reward so far: -103.51
#   Step 20, Reward so far: -135.48
#   Step 30, Reward so far: -261.83
#   Step 40, Reward so far: -756.53
#   Step 50, Reward so far: -1257.75
#   Step 60, Reward so far: -1846.42
#   Step 70, Reward so far: -2622.74
#   Step 80, Reward so far: -3521.27
#   Step 90, Reward so far: -4596.19
#   Step 100, Reward so far: -5754.21
# Episode 47/300 completed | Steps: 100 | Reward: -5754.21 | Epsilon: 0.19 | Time: 1.9s | Q-table size: 3422
# Model saved to enhanced_cloud_q_best.pkl
# New best model saved with reward: -5754.21
#
# Starting Episode 48/300...
#   Step 10, Reward so far: -142.49
#   Step 20, Reward so far: -286.73
#   Step 30, Reward so far: -676.43
#   Step 40, Reward so far: -1128.96
#   Step 50, Reward so far: -1826.13
#   Step 60, Reward so far: -2477.70
#   Step 70, Reward so far: -3273.85
#   Step 80, Reward so far: -4278.45
#   Step 90, Reward so far: -5494.80
#   Step 100, Reward so far: -6724.02
# Episode 48/300 completed | Steps: 100 | Reward: -6724.02 | Epsilon: 0.19 | Time: 1.9s | Q-table size: 3422
#
# Starting Episode 49/300...
#   Step 10, Reward so far: -139.29
#   Step 20, Reward so far: -350.56
#   Step 30, Reward so far: -630.65
#   Step 40, Reward so far: -1076.82
#   Step 50, Reward so far: -1709.38
#   Step 60, Reward so far: -2362.89
#   Step 70, Reward so far: -3179.23
#   Step 80, Reward so far: -4117.82
#   Step 90, Reward so far: -5199.13
#   Step 100, Reward so far: -6367.49
# Episode 49/300 completed | Steps: 100 | Reward: -6367.49 | Epsilon: 0.18 | Time: 2.0s | Q-table size: 3422
#
# Starting Episode 50/300...
#   Step 10, Reward so far: -193.31
#   Step 20, Reward so far: -305.01
#   Step 30, Reward so far: -782.61
#   Step 40, Reward so far: -1338.01
#   Step 50, Reward so far: -1949.62
#   Step 60, Reward so far: -2628.81
#   Step 70, Reward so far: -3431.43
#   Step 80, Reward so far: -4398.03
#   Step 90, Reward so far: -5551.27
#   Step 100, Reward so far: -6833.36
# Episode 50/300 completed | Steps: 100 | Reward: -6833.36 | Epsilon: 0.18 | Time: 2.0s | Q-table size: 3422
# Model saved to enhanced_cloud_q_ep50.pkl
#
# Starting Episode 51/300...
#   Step 10, Reward so far: -170.56
#   Step 20, Reward so far: -403.31
#   Step 30, Reward so far: -573.42
#   Step 40, Reward so far: -1022.87
#   Step 50, Reward so far: -1593.33
#   Step 60, Reward so far: -2229.39
#   Step 70, Reward so far: -3085.20
#   Step 80, Reward so far: -4147.97
#   Step 90, Reward so far: -5268.15
#   Step 100, Reward so far: -6544.43
# Episode 51/300 completed | Steps: 100 | Reward: -6544.43 | Epsilon: 0.18 | Time: 2.0s | Q-table size: 3422
#
# Starting Episode 52/300...
#   Step 10, Reward so far: -130.68
#   Step 20, Reward so far: -298.94
#   Step 30, Reward so far: -463.65
#   Step 40, Reward so far: -927.40
#   Step 50, Reward so far: -1536.16
#   Step 60, Reward so far: -2113.13
#   Step 70, Reward so far: -2825.85
#   Step 80, Reward so far: -3652.06
#   Step 90, Reward so far: -4679.84
#   Step 100, Reward so far: -5833.00
# Episode 52/300 completed | Steps: 100 | Reward: -5833.00 | Epsilon: 0.18 | Time: 2.0s | Q-table size: 3422
#
# Starting Episode 53/300...
#   Step 10, Reward so far: -185.77
#   Step 20, Reward so far: -254.77
#   Step 30, Reward so far: -344.18
#   Step 40, Reward so far: -753.77
#   Step 50, Reward so far: -1290.54
#   Step 60, Reward so far: -1898.44
#   Step 70, Reward so far: -2683.85
#   Step 80, Reward so far: -3641.25
#   Step 90, Reward so far: -4806.47
#   Step 100, Reward so far: -6005.66
# Episode 53/300 completed | Steps: 100 | Reward: -6005.66 | Epsilon: 0.18 | Time: 2.0s | Q-table size: 3431
#
# Starting Episode 54/300...
#   Step 10, Reward so far: -211.18
#   Step 20, Reward so far: -424.10
#   Step 30, Reward so far: -546.63
#   Step 40, Reward so far: -923.60
#   Step 50, Reward so far: -1582.28
#   Step 60, Reward so far: -2154.28
#   Step 70, Reward so far: -2932.17
#   Step 80, Reward so far: -3964.56
#   Step 90, Reward so far: -5031.88
#   Step 100, Reward so far: -6166.27
# Episode 54/300 completed | Steps: 100 | Reward: -6166.27 | Epsilon: 0.17 | Time: 2.1s | Q-table size: 3431
#
# Starting Episode 55/300...
#   Step 10, Reward so far: -132.05
#   Step 20, Reward so far: -375.93
#   Step 30, Reward so far: -634.50
#   Step 40, Reward so far: -1063.94
#   Step 50, Reward so far: -1710.99
#   Step 60, Reward so far: -2393.14
#   Step 70, Reward so far: -3234.31
#   Step 80, Reward so far: -4144.07
#   Step 90, Reward so far: -5281.82
#   Step 100, Reward so far: -6505.35
# Episode 55/300 completed | Steps: 100 | Reward: -6505.35 | Epsilon: 0.17 | Time: 2.1s | Q-table size: 3431
#
# Starting Episode 56/300...
#   Step 10, Reward so far: -155.18
#   Step 20, Reward so far: -287.49
#   Step 30, Reward so far: -534.45
#   Step 40, Reward so far: -987.71
#   Step 50, Reward so far: -1656.12
#   Step 60, Reward so far: -2259.21
#   Step 70, Reward so far: -3042.94
#   Step 80, Reward so far: -4070.64
#   Step 90, Reward so far: -5277.02
#   Step 100, Reward so far: -6441.76
# Episode 56/300 completed | Steps: 100 | Reward: -6441.76 | Epsilon: 0.17 | Time: 2.1s | Q-table size: 3440
#
# Starting Episode 57/300...
#   Step 10, Reward so far: -125.89
#   Step 20, Reward so far: -446.67
#   Step 30, Reward so far: -642.52
#   Step 40, Reward so far: -1112.88
#   Step 50, Reward so far: -1706.18
#   Step 60, Reward so far: -2309.94
#   Step 70, Reward so far: -3038.52
#   Step 80, Reward so far: -3841.97
#   Step 90, Reward so far: -4871.29
#   Step 100, Reward so far: -5841.61
# Episode 57/300 completed | Steps: 100 | Reward: -5841.61 | Epsilon: 0.17 | Time: 2.1s | Q-table size: 3440
#
# Starting Episode 58/300...
#   Step 10, Reward so far: -137.79
#   Step 20, Reward so far: -249.43
#   Step 30, Reward so far: -535.73
#   Step 40, Reward so far: -1077.10
#   Step 50, Reward so far: -1800.03
#   Step 60, Reward so far: -2560.24
#   Step 70, Reward so far: -3449.97
#   Step 80, Reward so far: -4568.47
#   Step 90, Reward so far: -5806.03
#   Step 100, Reward so far: -7098.20
# Episode 58/300 completed | Steps: 100 | Reward: -7098.20 | Epsilon: 0.17 | Time: 2.2s | Q-table size: 3440
#
# Starting Episode 59/300...
#   Step 10, Reward so far: -83.65
#   Step 20, Reward so far: -280.03
#   Step 30, Reward so far: -319.62
#   Step 40, Reward so far: -680.26
#   Step 50, Reward so far: -1433.44
#   Step 60, Reward so far: -2004.51
#   Step 70, Reward so far: -2819.25
#   Step 80, Reward so far: -3749.70
#   Step 90, Reward so far: -4923.72
#   Step 100, Reward so far: -6171.08
# Episode 59/300 completed | Steps: 100 | Reward: -6171.08 | Epsilon: 0.17 | Time: 2.2s | Q-table size: 3440
#
# Starting Episode 60/300...
#   Step 10, Reward so far: -100.15
#   Step 20, Reward so far: -364.43
#   Step 30, Reward so far: -638.22
#   Step 40, Reward so far: -1135.58
#   Step 50, Reward so far: -1759.13
#   Step 60, Reward so far: -2401.97
#   Step 70, Reward so far: -3169.08
#   Step 80, Reward so far: -4136.51
#   Step 90, Reward so far: -5245.77
#   Step 100, Reward so far: -6343.79
# Episode 60/300 completed | Steps: 100 | Reward: -6343.79 | Epsilon: 0.16 | Time: 2.2s | Q-table size: 3440
# Model saved to enhanced_cloud_q_ep60.pkl
#
# Starting Episode 61/300...
#   Step 10, Reward so far: -99.65
#   Step 20, Reward so far: -297.53
#   Step 30, Reward so far: -483.62
#   Step 40, Reward so far: -952.44
#   Step 50, Reward so far: -1700.85
#   Step 60, Reward so far: -2363.52
#   Step 70, Reward so far: -3158.62
#   Step 80, Reward so far: -4102.03
#   Step 90, Reward so far: -5220.46
#   Step 100, Reward so far: -6366.60
# Episode 61/300 completed | Steps: 100 | Reward: -6366.60 | Epsilon: 0.16 | Time: 2.6s | Q-table size: 3443
#
# Starting Episode 62/300...
#   Step 10, Reward so far: -132.67
#   Step 20, Reward so far: -262.86
#   Step 30, Reward so far: -307.20
#   Step 40, Reward so far: -707.38
#   Step 50, Reward so far: -1268.55
#   Step 60, Reward so far: -1809.51
#   Step 70, Reward so far: -2524.02
#   Step 80, Reward so far: -3388.20
#   Step 90, Reward so far: -4440.65
#   Step 100, Reward so far: -5523.64
# Episode 62/300 completed | Steps: 100 | Reward: -5523.64 | Epsilon: 0.16 | Time: 2.7s | Q-table size: 3458
# Model saved to enhanced_cloud_q_best.pkl
# New best model saved with reward: -5523.64
#
# Starting Episode 63/300...
#   Step 10, Reward so far: -132.05
#   Step 20, Reward so far: -310.56
#   Step 30, Reward so far: -465.87
#   Step 40, Reward so far: -859.23
#   Step 50, Reward so far: -1395.39
#   Step 60, Reward so far: -1972.55
#   Step 70, Reward so far: -2576.71
#   Step 80, Reward so far: -3229.43
#   Step 90, Reward so far: -4004.50
#   Step 100, Reward so far: -4918.39
# Episode 63/300 completed | Steps: 100 | Reward: -4918.39 | Epsilon: 0.16 | Time: 2.7s | Q-table size: 3527
# Model saved to enhanced_cloud_q_best.pkl
# New best model saved with reward: -4918.39
#
# Starting Episode 64/300...
#   Step 10, Reward so far: -126.43
#   Step 20, Reward so far: -234.71
#   Step 30, Reward so far: -578.04
#   Step 40, Reward so far: -1167.44
#   Step 50, Reward so far: -1877.24
#   Step 60, Reward so far: -2522.17
#   Step 70, Reward so far: -3352.49
#   Step 80, Reward so far: -4259.06
#   Step 90, Reward so far: -5391.87
#   Step 100, Reward so far: -6511.05
# Episode 64/300 completed | Steps: 100 | Reward: -6511.05 | Epsilon: 0.16 | Time: 2.7s | Q-table size: 3527
#
# Starting Episode 65/300...
#   Step 10, Reward so far: -106.68
#   Step 20, Reward so far: -236.87
#   Step 30, Reward so far: -275.32
#   Step 40, Reward so far: -735.77
#   Step 50, Reward so far: -1465.19
#   Step 60, Reward so far: -2138.03
#   Step 70, Reward so far: -2957.06
#   Step 80, Reward so far: -3900.35
#   Step 90, Reward so far: -5025.06
#   Step 100, Reward so far: -6144.07
# Episode 65/300 completed | Steps: 100 | Reward: -6144.07 | Epsilon: 0.16 | Time: 2.8s | Q-table size: 3527
#
# Starting Episode 66/300...
#   Step 10, Reward so far: -215.00
#   Step 20, Reward so far: -488.09
#   Step 30, Reward so far: -740.05
#   Step 40, Reward so far: -1106.21
#   Step 50, Reward so far: -1609.38
#   Step 60, Reward so far: -2176.10
#   Step 70, Reward so far: -2872.21
#   Step 80, Reward so far: -3625.47
#   Step 90, Reward so far: -4566.61
#   Step 100, Reward so far: -5559.09
# Episode 66/300 completed | Steps: 100 | Reward: -5559.09 | Epsilon: 0.15 | Time: 2.8s | Q-table size: 3527
#
# Starting Episode 67/300...
#   Step 10, Reward so far: -98.22
#   Step 20, Reward so far: -280.42
#   Step 30, Reward so far: -678.03
#   Step 40, Reward so far: -1186.92
#   Step 50, Reward so far: -1787.27
#   Step 60, Reward so far: -2438.71
#   Step 70, Reward so far: -3170.25
#   Step 80, Reward so far: -3975.09
#   Step 90, Reward so far: -4938.12
#   Step 100, Reward so far: -5932.28
# Episode 67/300 completed | Steps: 100 | Reward: -5932.28 | Epsilon: 0.15 | Time: 2.8s | Q-table size: 3527
#
# Starting Episode 68/300...
#   Step 10, Reward so far: -115.03
#   Step 20, Reward so far: -310.70
#   Step 30, Reward so far: -420.35
#   Step 40, Reward so far: -922.85
#   Step 50, Reward so far: -1491.96
#   Step 60, Reward so far: -2146.64
#   Step 70, Reward so far: -2891.56
#   Step 80, Reward so far: -3750.27
#   Step 90, Reward so far: -4762.23
#   Step 100, Reward so far: -5743.72
# Episode 68/300 completed | Steps: 100 | Reward: -5743.72 | Epsilon: 0.15 | Time: 2.8s | Q-table size: 3530
#
# Starting Episode 69/300...
#   Step 10, Reward so far: -110.26
#   Step 20, Reward so far: -190.33
#   Step 30, Reward so far: -495.79
#   Step 40, Reward so far: -1019.05
#   Step 50, Reward so far: -1633.96
#   Step 60, Reward so far: -2251.03
#   Step 70, Reward so far: -3013.77
#   Step 80, Reward so far: -3855.21
#   Step 90, Reward so far: -4845.57
#   Step 100, Reward so far: -5911.43
# Episode 69/300 completed | Steps: 100 | Reward: -5911.43 | Epsilon: 0.15 | Time: 2.9s | Q-table size: 3530
#
# Starting Episode 70/300...
#   Step 10, Reward so far: -83.65
#   Step 20, Reward so far: -288.29
#   Step 30, Reward so far: -606.75
#   Step 40, Reward so far: -994.91
#   Step 50, Reward so far: -1483.37
#   Step 60, Reward so far: -2093.12
#   Step 70, Reward so far: -2786.95
#   Step 80, Reward so far: -3657.91
#   Step 90, Reward so far: -4686.31
#   Step 100, Reward so far: -5740.29
# Episode 70/300 completed | Steps: 100 | Reward: -5740.29 | Epsilon: 0.15 | Time: 2.9s | Q-table size: 3536
# Model saved to enhanced_cloud_q_ep70.pkl
#
# Starting Episode 71/300...
#   Step 10, Reward so far: -91.30
#   Step 20, Reward so far: -234.43
#   Step 30, Reward so far: -407.77
#   Step 40, Reward so far: -826.10
#   Step 50, Reward so far: -1427.65
#   Step 60, Reward so far: -2058.20
#   Step 70, Reward so far: -2772.23
#   Step 80, Reward so far: -3539.90
#   Step 90, Reward so far: -4499.46
#   Step 100, Reward so far: -5395.60
# Episode 71/300 completed | Steps: 100 | Reward: -5395.60 | Epsilon: 0.15 | Time: 2.9s | Q-table size: 3536
#
# Starting Episode 72/300...
#   Step 10, Reward so far: -122.16
#   Step 20, Reward so far: -261.18
#   Step 30, Reward so far: -397.08
#   Step 40, Reward so far: -810.89
#   Step 50, Reward so far: -1450.43
#   Step 60, Reward so far: -2026.61
#   Step 70, Reward so far: -2682.74
#   Step 80, Reward so far: -3472.26
#   Step 90, Reward so far: -4376.98
#   Step 100, Reward so far: -5357.68
# Episode 72/300 completed | Steps: 100 | Reward: -5357.68 | Epsilon: 0.15 | Time: 2.9s | Q-table size: 3536
#
# Starting Episode 73/300...
#   Step 10, Reward so far: -120.90
#   Step 20, Reward so far: -358.32
#   Step 30, Reward so far: -724.04
#   Step 40, Reward so far: -1253.09
#   Step 50, Reward so far: -1800.05
#   Step 60, Reward so far: -2386.28
#   Step 70, Reward so far: -3047.03
#   Step 80, Reward so far: -3762.38
#   Step 90, Reward so far: -4657.00
#   Step 100, Reward so far: -5515.88
# Episode 73/300 completed | Steps: 100 | Reward: -5515.88 | Epsilon: 0.14 | Time: 2.9s | Q-table size: 3536
#
# Starting Episode 74/300...
#   Step 10, Reward so far: -106.68
#   Step 20, Reward so far: -211.58
#   Step 30, Reward so far: -319.36
#   Step 40, Reward so far: -700.62
#   Step 50, Reward so far: -1231.45
#   Step 60, Reward so far: -1858.50
#   Step 70, Reward so far: -2529.60
#   Step 80, Reward so far: -3267.86
#   Step 90, Reward so far: -4202.41
#   Step 100, Reward so far: -5161.02
# Episode 74/300 completed | Steps: 100 | Reward: -5161.02 | Epsilon: 0.14 | Time: 3.0s | Q-table size: 3536
#
# Starting Episode 75/300...
#   Step 10, Reward so far: -75.03
#   Step 20, Reward so far: -204.47
#   Step 30, Reward so far: -416.71
#   Step 40, Reward so far: -875.37
#   Step 50, Reward so far: -1496.07
#   Step 60, Reward so far: -2129.31
#   Step 70, Reward so far: -2914.20
#   Step 80, Reward so far: -3826.49
#   Step 90, Reward so far: -4863.44
#   Step 100, Reward so far: -5797.83
# Episode 75/300 completed | Steps: 100 | Reward: -5797.83 | Epsilon: 0.14 | Time: 3.0s | Q-table size: 3536
#
# Starting Episode 76/300...
#   Step 10, Reward so far: -126.40
#   Step 20, Reward so far: -331.02
#   Step 30, Reward so far: -526.05
#   Step 40, Reward so far: -974.75
#   Step 50, Reward so far: -1552.67
#   Step 60, Reward so far: -2189.58
#   Step 70, Reward so far: -2918.99
#   Step 80, Reward so far: -3719.70
#   Step 90, Reward so far: -4740.89
#   Step 100, Reward so far: -5813.26
# Episode 76/300 completed | Steps: 100 | Reward: -5813.26 | Epsilon: 0.14 | Time: 3.0s | Q-table size: 3536
#
# Starting Episode 77/300...
#   Step 10, Reward so far: -75.65
#   Step 20, Reward so far: -196.55
#   Step 30, Reward so far: -273.85
#   Step 40, Reward so far: -669.26
#   Step 50, Reward so far: -1188.25
#   Step 60, Reward so far: -1800.99
#   Step 70, Reward so far: -2488.67
#   Step 80, Reward so far: -3304.08
#   Step 90, Reward so far: -4278.25
#   Step 100, Reward so far: -5271.65
# Episode 77/300 completed | Steps: 100 | Reward: -5271.65 | Epsilon: 0.14 | Time: 3.0s | Q-table size: 3536
#
# Starting Episode 78/300...
#   Step 10, Reward so far: -75.03
#   Step 20, Reward so far: -218.08
#   Step 30, Reward so far: -409.49
#   Step 40, Reward so far: -868.66
#   Step 50, Reward so far: -1377.43
#   Step 60, Reward so far: -1962.82
#   Step 70, Reward so far: -2726.44
#   Step 80, Reward so far: -3472.20
#   Step 90, Reward so far: -4330.34
#   Step 100, Reward so far: -5279.69
# Episode 78/300 completed | Steps: 100 | Reward: -5279.69 | Epsilon: 0.14 | Time: 3.1s | Q-table size: 3536
#
# Starting Episode 79/300...
#   Step 10, Reward so far: -148.75
#   Step 20, Reward so far: -378.16
#   Step 30, Reward so far: -466.14
#   Step 40, Reward so far: -1058.31
#   Step 50, Reward so far: -1720.18
#   Step 60, Reward so far: -2309.48
#   Step 70, Reward so far: -3033.45
#   Step 80, Reward so far: -3868.76
#   Step 90, Reward so far: -4861.58
#   Step 100, Reward so far: -5934.99
# Episode 79/300 completed | Steps: 100 | Reward: -5934.99 | Epsilon: 0.14 | Time: 3.1s | Q-table size: 3536
#
# Starting Episode 80/300...
#   Step 10, Reward so far: -83.65
#   Step 20, Reward so far: -322.81
#   Step 30, Reward so far: -537.39
#   Step 40, Reward so far: -999.87
#   Step 50, Reward so far: -1569.89
#   Step 60, Reward so far: -2163.12
#   Step 70, Reward so far: -2981.25
#   Step 80, Reward so far: -3846.78
#   Step 90, Reward so far: -4796.32
#   Step 100, Reward so far: -5724.03
# Episode 80/300 completed | Steps: 100 | Reward: -5724.03 | Epsilon: 0.13 | Time: 3.1s | Q-table size: 3536
# Model saved to enhanced_cloud_q_ep80.pkl
#
# Starting Episode 81/300...
#   Step 10, Reward so far: -75.65
#   Step 20, Reward so far: -253.19
#   Step 30, Reward so far: -466.20
#   Step 40, Reward so far: -840.24
#   Step 50, Reward so far: -1383.21
#   Step 60, Reward so far: -1995.27
#   Step 70, Reward so far: -2711.37
#   Step 80, Reward so far: -3434.71
#   Step 90, Reward so far: -4313.74
#   Step 100, Reward so far: -5274.81
# Episode 81/300 completed | Steps: 100 | Reward: -5274.81 | Epsilon: 0.13 | Time: 3.5s | Q-table size: 3545
#
# Starting Episode 82/300...
#   Step 10, Reward so far: -120.07
#   Step 20, Reward so far: -299.65
#   Step 30, Reward so far: -480.77
#   Step 40, Reward so far: -911.12
#   Step 50, Reward so far: -1424.69
#   Step 60, Reward so far: -2113.04
#   Step 70, Reward so far: -2824.19
#   Step 80, Reward so far: -3659.95
#   Step 90, Reward so far: -4615.97
#   Step 100, Reward so far: -5616.43
# Episode 82/300 completed | Steps: 100 | Reward: -5616.43 | Epsilon: 0.13 | Time: 3.5s | Q-table size: 3545
#
# Starting Episode 83/300...
#   Step 10, Reward so far: -75.65
#   Step 20, Reward so far: -282.07
#   Step 30, Reward so far: -619.81
#   Step 40, Reward so far: -1190.41
#   Step 50, Reward so far: -1786.14
#   Step 60, Reward so far: -2459.19
#   Step 70, Reward so far: -3383.45
#   Step 80, Reward so far: -4321.94
#   Step 90, Reward so far: -5482.44
#   Step 100, Reward so far: -6685.43
# Episode 83/300 completed | Steps: 100 | Reward: -6685.43 | Epsilon: 0.13 | Time: 3.6s | Q-table size: 3545
#
# Starting Episode 84/300...
#   Step 10, Reward so far: -91.14
#   Step 20, Reward so far: -247.02
#   Step 30, Reward so far: -383.76
#   Step 40, Reward so far: -782.06
#   Step 50, Reward so far: -1250.75
#   Step 60, Reward so far: -1795.18
#   Step 70, Reward so far: -2566.98
#   Step 80, Reward so far: -3368.33
#   Step 90, Reward so far: -4465.48
#   Step 100, Reward so far: -5562.86
# Episode 84/300 completed | Steps: 100 | Reward: -5562.86 | Epsilon: 0.13 | Time: 3.6s | Q-table size: 3584
#
# Starting Episode 85/300...
#   Step 10, Reward so far: -154.47
#   Step 20, Reward so far: -298.26
#   Step 30, Reward so far: -741.35
#   Step 40, Reward so far: -1174.27
#   Step 50, Reward so far: -1823.86
#   Step 60, Reward so far: -2403.52
#   Step 70, Reward so far: -3233.54
#   Step 80, Reward so far: -4013.97
#   Step 90, Reward so far: -5010.59
#   Step 100, Reward so far: -6012.02
# Episode 85/300 completed | Steps: 100 | Reward: -6012.02 | Epsilon: 0.13 | Time: 3.7s | Q-table size: 3587
#
# Starting Episode 86/300...
#   Step 10, Reward so far: -127.69
#   Step 20, Reward so far: -383.14
#   Step 30, Reward so far: -694.09
#   Step 40, Reward so far: -1155.47
#   Step 50, Reward so far: -1744.10
#   Step 60, Reward so far: -2414.11
#   Step 70, Reward so far: -3273.68
#   Step 80, Reward so far: -4174.56
#   Step 90, Reward so far: -5320.01
#   Step 100, Reward so far: -6468.39
# Episode 86/300 completed | Steps: 100 | Reward: -6468.39 | Epsilon: 0.13 | Time: 3.7s | Q-table size: 3587
#
# Starting Episode 87/300...
#   Step 10, Reward so far: -125.93
#   Step 20, Reward so far: -269.63
#   Step 30, Reward so far: -428.92
#   Step 40, Reward so far: -909.37
#   Step 50, Reward so far: -1552.00
#   Step 60, Reward so far: -2149.68
#   Step 70, Reward so far: -2862.00
#   Step 80, Reward so far: -3715.05
#   Step 90, Reward so far: -4623.44
#   Step 100, Reward so far: -5590.53
# Episode 87/300 completed | Steps: 100 | Reward: -5590.53 | Epsilon: 0.13 | Time: 3.7s | Q-table size: 3587
#
# Starting Episode 88/300...
#   Step 10, Reward so far: -162.10
#   Step 20, Reward so far: -317.12
#   Step 30, Reward so far: -640.31
#   Step 40, Reward so far: -1129.87
#   Step 50, Reward so far: -1694.54
#   Step 60, Reward so far: -2298.47
#   Step 70, Reward so far: -3031.39
#   Step 80, Reward so far: -3813.94
#   Step 90, Reward so far: -4844.57
#   Step 100, Reward so far: -5932.19
# Episode 88/300 completed | Steps: 100 | Reward: -5932.19 | Epsilon: 0.12 | Time: 3.8s | Q-table size: 3587
#
# Starting Episode 89/300...
#   Step 10, Reward so far: -219.29
#   Step 20, Reward so far: -456.71
#   Step 30, Reward so far: -856.21
#   Step 40, Reward so far: -1342.37
#   Step 50, Reward so far: -1896.89
#   Step 60, Reward so far: -2475.20
#   Step 70, Reward so far: -3217.60
#   Step 80, Reward so far: -3931.35
#   Step 90, Reward so far: -4824.60
#   Step 100, Reward so far: -5758.36
# Episode 89/300 completed | Steps: 100 | Reward: -5758.36 | Epsilon: 0.12 | Time: 3.8s | Q-table size: 3590
#
# Starting Episode 90/300...
#   Step 10, Reward so far: -131.18
#   Step 20, Reward so far: -258.88
#   Step 30, Reward so far: -437.82
#   Step 40, Reward so far: -811.93
#   Step 50, Reward so far: -1412.23
#   Step 60, Reward so far: -1952.21
#   Step 70, Reward so far: -2691.93
#   Step 80, Reward so far: -3508.12
#   Step 90, Reward so far: -4545.27
#   Step 100, Reward so far: -5635.10
# Episode 90/300 completed | Steps: 100 | Reward: -5635.10 | Epsilon: 0.12 | Time: 3.8s | Q-table size: 3590
# Model saved to enhanced_cloud_q_ep90.pkl
#
# Starting Episode 91/300...
#   Step 10, Reward so far: -142.49
#   Step 20, Reward so far: -289.51
#   Step 30, Reward so far: -737.66
#   Step 40, Reward so far: -1204.87
#   Step 50, Reward so far: -1706.29
#   Step 60, Reward so far: -2316.43
#   Step 70, Reward so far: -3037.83
#   Step 80, Reward so far: -3900.52
#   Step 90, Reward so far: -4873.54
#   Step 100, Reward so far: -5876.53
# Episode 91/300 completed | Steps: 100 | Reward: -5876.53 | Epsilon: 0.12 | Time: 3.8s | Q-table size: 3590
#
# Starting Episode 92/300...
#   Step 10, Reward so far: -120.90
#   Step 20, Reward so far: -373.49
#   Step 30, Reward so far: -446.72
#   Step 40, Reward so far: -949.48
#   Step 50, Reward so far: -1621.47
#   Step 60, Reward so far: -2245.93
#   Step 70, Reward so far: -2979.58
#   Step 80, Reward so far: -3827.64
#   Step 90, Reward so far: -4904.56
#   Step 100, Reward so far: -6000.44
# Episode 92/300 completed | Steps: 100 | Reward: -6000.44 | Epsilon: 0.12 | Time: 3.9s | Q-table size: 3590
#
# Starting Episode 93/300...
#   Step 10, Reward so far: -132.05
#   Step 20, Reward so far: -252.95
#   Step 30, Reward so far: -453.70
#   Step 40, Reward so far: -922.04
#   Step 50, Reward so far: -1527.28
#   Step 60, Reward so far: -2170.14
#   Step 70, Reward so far: -2965.48
#   Step 80, Reward so far: -3848.15
#   Step 90, Reward so far: -4959.78
#   Step 100, Reward so far: -6021.58
# Episode 93/300 completed | Steps: 100 | Reward: -6021.58 | Epsilon: 0.12 | Time: 3.9s | Q-table size: 3590
#
# Starting Episode 94/300...
#   Step 10, Reward so far: -134.83
#   Step 20, Reward so far: -292.25
#   Step 30, Reward so far: -487.97
#   Step 40, Reward so far: -938.55
#   Step 50, Reward so far: -1538.13
#   Step 60, Reward so far: -2146.76
#   Step 70, Reward so far: -2918.55
#   Step 80, Reward so far: -3681.45
#   Step 90, Reward so far: -4686.46
#   Step 100, Reward so far: -5635.01
# Episode 94/300 completed | Steps: 100 | Reward: -5635.01 | Epsilon: 0.12 | Time: 3.9s | Q-table size: 3590
#
# Starting Episode 95/300...
#   Step 10, Reward so far: -200.88
#   Step 20, Reward so far: -380.98
#   Step 30, Reward so far: -788.75
#   Step 40, Reward so far: -1284.62
#   Step 50, Reward so far: -1859.69
#   Step 60, Reward so far: -2426.45
#   Step 70, Reward so far: -3077.15
#   Step 80, Reward so far: -3773.04
#   Step 90, Reward so far: -4670.95
#   Step 100, Reward so far: -5599.30
# Episode 95/300 completed | Steps: 100 | Reward: -5599.30 | Epsilon: 0.12 | Time: 3.9s | Q-table size: 3590
#
# Starting Episode 96/300...
#   Step 10, Reward so far: -75.03
#   Step 20, Reward so far: -288.69
#   Step 30, Reward so far: -434.93
#   Step 40, Reward so far: -861.31
#   Step 50, Reward so far: -1619.38
#   Step 60, Reward so far: -2242.13
#   Step 70, Reward so far: -3015.16
#   Step 80, Reward so far: -3828.32
#   Step 90, Reward so far: -4832.62
#   Step 100, Reward so far: -5817.10
# Episode 96/300 completed | Steps: 100 | Reward: -5817.10 | Epsilon: 0.11 | Time: 3.9s | Q-table size: 3590
#
# Starting Episode 97/300...
#   Step 10, Reward so far: -99.65
#   Step 20, Reward so far: -250.70
# ...
#   Step 50, Reward so far: -1439.27
#   Step 60, Reward so far: -1959.40
#   Step 70, Reward so far: -2607.01
#   Step 80, Reward so far: -3302.49
#   Step 90, Reward so far: -4174.17
#   Step 100, Reward so far: -5024.63
# Episode 271/300 completed | Steps: 100 | Reward: -5024.63 | Epsilon: 0.05 | Time: 13.3s | Q-table size: 3779
#
# Starting Episode 272/300...
#   Step 10, Reward so far: -91.14
#   Step 20, Reward so far: -213.55
#   Step 30, Reward so far: -448.52
#   Step 40, Reward so far: -823.91
#   Step 50, Reward so far: -1360.93
#   Step 60, Reward so far: -1895.54
#   Step 70, Reward so far: -2524.14
#   Step 80, Reward so far: -3202.31
#   Step 90, Reward so far: -4132.22
#   Step 100, Reward so far: -5172.25
# Episode 272/300 completed | Steps: 100 | Reward: -5172.25 | Epsilon: 0.05 | Time: 13.5s | Q-table size: 3782
#
# Starting Episode 273/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -371.17
#   Step 40, Reward so far: -737.89
#   Step 50, Reward so far: -1247.99
#   Step 60, Reward so far: -1786.43
#   Step 70, Reward so far: -2382.07
#   Step 80, Reward so far: -3049.71
#   Step 90, Reward so far: -3967.85
#   Step 100, Reward so far: -4954.90
# Episode 273/300 completed | Steps: 100 | Reward: -4954.90 | Epsilon: 0.05 | Time: 13.5s | Q-table size: 3785
#
# Starting Episode 274/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -371.17
#   Step 40, Reward so far: -852.78
#   Step 50, Reward so far: -1345.11
#   Step 60, Reward so far: -1893.69
#   Step 70, Reward so far: -2555.87
#   Step 80, Reward so far: -3224.88
#   Step 90, Reward so far: -4029.70
#   Step 100, Reward so far: -4904.70
# Episode 274/300 completed | Steps: 100 | Reward: -4904.70 | Epsilon: 0.05 | Time: 13.6s | Q-table size: 3785
#
# Starting Episode 275/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -371.17
#   Step 40, Reward so far: -757.11
#   Step 50, Reward so far: -1246.96
#   Step 60, Reward so far: -1783.09
#   Step 70, Reward so far: -2434.49
#   Step 80, Reward so far: -3111.23
#   Step 90, Reward so far: -3961.10
#   Step 100, Reward so far: -4781.38
# Episode 275/300 completed | Steps: 100 | Reward: -4781.38 | Epsilon: 0.05 | Time: 13.7s | Q-table size: 3785
#
# Starting Episode 276/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -371.17
#   Step 40, Reward so far: -892.71
#   Step 50, Reward so far: -1524.77
#   Step 60, Reward so far: -2148.99
#   Step 70, Reward so far: -2894.26
#   Step 80, Reward so far: -3686.54
#   Step 90, Reward so far: -4628.01
#   Step 100, Reward so far: -5595.15
# Episode 276/300 completed | Steps: 100 | Reward: -5595.15 | Epsilon: 0.05 | Time: 13.8s | Q-table size: 3785
#
# Starting Episode 277/300...
#   Step 10, Reward so far: -132.05
#   Step 20, Reward so far: -296.60
#   Step 30, Reward so far: -447.11
#   Step 40, Reward so far: -837.84
#   Step 50, Reward so far: -1354.69
#   Step 60, Reward so far: -1926.13
#   Step 70, Reward so far: -2642.89
#   Step 80, Reward so far: -3436.27
#   Step 90, Reward so far: -4405.14
#   Step 100, Reward so far: -5280.31
# Episode 277/300 completed | Steps: 100 | Reward: -5280.31 | Epsilon: 0.05 | Time: 13.9s | Q-table size: 3785
#
# Starting Episode 278/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -371.17
#   Step 40, Reward so far: -683.18
#   Step 50, Reward so far: -1027.66
#   Step 60, Reward so far: -1545.80
#   Step 70, Reward so far: -2205.40
#   Step 80, Reward so far: -2917.29
#   Step 90, Reward so far: -3812.99
#   Step 100, Reward so far: -4762.67
# Episode 278/300 completed | Steps: 100 | Reward: -4762.67 | Epsilon: 0.05 | Time: 13.9s | Q-table size: 3785
#
# Starting Episode 279/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -371.17
#   Step 40, Reward so far: -799.62
#   Step 50, Reward so far: -1350.61
#   Step 60, Reward so far: -1970.02
#   Step 70, Reward so far: -2770.22
#   Step 80, Reward so far: -3562.50
#   Step 90, Reward so far: -4623.17
#   Step 100, Reward so far: -5635.45
# Episode 279/300 completed | Steps: 100 | Reward: -5635.45 | Epsilon: 0.05 | Time: 14.0s | Q-table size: 3785
#
# Starting Episode 280/300...
#   Step 10, Reward so far: -80.13
#   Step 20, Reward so far: -201.78
#   Step 30, Reward so far: -352.28
#   Step 40, Reward so far: -702.00
#   Step 50, Reward so far: -1308.18
#   Step 60, Reward so far: -1900.00
#   Step 70, Reward so far: -2610.58
#   Step 80, Reward so far: -3369.59
#   Step 90, Reward so far: -4236.65
#   Step 100, Reward so far: -5172.30
# Episode 280/300 completed | Steps: 100 | Reward: -5172.30 | Epsilon: 0.05 | Time: 14.1s | Q-table size: 3785
# Model saved to enhanced_cloud_q_ep280.pkl
#
# Starting Episode 281/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -429.15
#   Step 40, Reward so far: -852.08
#   Step 50, Reward so far: -1390.53
#   Step 60, Reward so far: -1938.72
#   Step 70, Reward so far: -2567.33
#   Step 80, Reward so far: -3254.37
#   Step 90, Reward so far: -4132.90
#   Step 100, Reward so far: -4916.63
# Episode 281/300 completed | Steps: 100 | Reward: -4916.63 | Epsilon: 0.05 | Time: 14.9s | Q-table size: 3785
#
# Starting Episode 282/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -219.93
#   Step 30, Reward so far: -302.97
#   Step 40, Reward so far: -638.68
#   Step 50, Reward so far: -1034.97
#   Step 60, Reward so far: -1571.33
#   Step 70, Reward so far: -2211.12
#   Step 80, Reward so far: -2901.56
#   Step 90, Reward so far: -3754.42
#   Step 100, Reward so far: -4605.77
# Episode 282/300 completed | Steps: 100 | Reward: -4605.77 | Epsilon: 0.05 | Time: 15.0s | Q-table size: 3785
# Model saved to enhanced_cloud_q_best.pkl
# New best model saved with reward: -4605.77
#
# Starting Episode 283/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -253.23
#   Step 30, Reward so far: -463.50
#   Step 40, Reward so far: -829.42
#   Step 50, Reward so far: -1416.47
#   Step 60, Reward so far: -1916.30
#   Step 70, Reward so far: -2575.70
#   Step 80, Reward so far: -3244.75
#   Step 90, Reward so far: -4118.07
#   Step 100, Reward so far: -5030.31
# Episode 283/300 completed | Steps: 100 | Reward: -5030.31 | Epsilon: 0.05 | Time: 15.0s | Q-table size: 3785
#
# Starting Episode 284/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -371.17
#   Step 40, Reward so far: -746.33
#   Step 50, Reward so far: -1172.08
#   Step 60, Reward so far: -1766.80
#   Step 70, Reward so far: -2476.97
#   Step 80, Reward so far: -3193.60
#   Step 90, Reward so far: -4136.11
#   Step 100, Reward so far: -5075.57
# Episode 284/300 completed | Steps: 100 | Reward: -5075.57 | Epsilon: 0.05 | Time: 15.1s | Q-table size: 3785
#
# Starting Episode 285/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -253.23
#   Step 30, Reward so far: -438.56
#   Step 40, Reward so far: -912.94
#   Step 50, Reward so far: -1544.61
#   Step 60, Reward so far: -2082.49
#   Step 70, Reward so far: -2754.11
#   Step 80, Reward so far: -3462.85
#   Step 90, Reward so far: -4363.94
#   Step 100, Reward so far: -5295.23
# Episode 285/300 completed | Steps: 100 | Reward: -5295.23 | Epsilon: 0.05 | Time: 15.2s | Q-table size: 3803
#
# Starting Episode 286/300...
#   Step 10, Reward so far: -75.03
#   Step 20, Reward so far: -196.67
#   Step 30, Reward so far: -347.17
#   Step 40, Reward so far: -680.62
#   Step 50, Reward so far: -1130.32
#   Step 60, Reward so far: -1654.26
#   Step 70, Reward so far: -2280.38
#   Step 80, Reward so far: -2953.89
#   Step 90, Reward so far: -3832.25
#   Step 100, Reward so far: -4666.90
# Episode 286/300 completed | Steps: 100 | Reward: -4666.90 | Epsilon: 0.05 | Time: 15.2s | Q-table size: 3803
#
# Starting Episode 287/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -253.23
#   Step 30, Reward so far: -438.56
#   Step 40, Reward so far: -894.91
#   Step 50, Reward so far: -1313.61
#   Step 60, Reward so far: -1905.22
#   Step 70, Reward so far: -2627.75
#   Step 80, Reward so far: -3353.77
#   Step 90, Reward so far: -4296.33
#   Step 100, Reward so far: -5335.67
# Episode 287/300 completed | Steps: 100 | Reward: -5335.67 | Epsilon: 0.05 | Time: 15.2s | Q-table size: 3803
#
# Starting Episode 288/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -572.06
#   Step 40, Reward so far: -1004.44
#   Step 50, Reward so far: -1544.68
#   Step 60, Reward so far: -2210.56
#   Step 70, Reward so far: -3054.12
#   Step 80, Reward so far: -3854.58
#   Step 90, Reward so far: -4800.12
#   Step 100, Reward so far: -5733.37
# Episode 288/300 completed | Steps: 100 | Reward: -5733.37 | Epsilon: 0.05 | Time: 15.2s | Q-table size: 3803
#
# Starting Episode 289/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -371.17
#   Step 40, Reward so far: -816.11
#   Step 50, Reward so far: -1212.15
#   Step 60, Reward so far: -1741.85
#   Step 70, Reward so far: -2448.18
#   Step 80, Reward so far: -3117.23
#   Step 90, Reward so far: -3990.54
#   Step 100, Reward so far: -4833.70
# Episode 289/300 completed | Steps: 100 | Reward: -4833.70 | Epsilon: 0.05 | Time: 15.3s | Q-table size: 3803
#
# Starting Episode 290/300...
#   Step 10, Reward so far: -75.03
#   Step 20, Reward so far: -180.67
#   Step 30, Reward so far: -331.17
#   Step 40, Reward so far: -747.14
#   Step 50, Reward so far: -1307.25
#   Step 60, Reward so far: -1838.46
#   Step 70, Reward so far: -2542.78
#   Step 80, Reward so far: -3257.93
#   Step 90, Reward so far: -4177.17
#   Step 100, Reward so far: -5038.42
# Episode 290/300 completed | Steps: 100 | Reward: -5038.42 | Epsilon: 0.05 | Time: 15.3s | Q-table size: 3809
# Model saved to enhanced_cloud_q_ep290.pkl
#
# Starting Episode 291/300...
#   Step 10, Reward so far: -99.65
#   Step 20, Reward so far: -221.29
#   Step 30, Reward so far: -371.80
#   Step 40, Reward so far: -739.37
#   Step 50, Reward so far: -1162.14
#   Step 60, Reward so far: -1743.80
#   Step 70, Reward so far: -2492.67
#   Step 80, Reward so far: -3215.50
#   Step 90, Reward so far: -4158.91
#   Step 100, Reward so far: -5010.42
# Episode 291/300 completed | Steps: 100 | Reward: -5010.42 | Epsilon: 0.05 | Time: 15.4s | Q-table size: 3809
#
# Starting Episode 292/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -202.12
#   Step 30, Reward so far: -404.15
#   Step 40, Reward so far: -822.14
#   Step 50, Reward so far: -1390.71
#   Step 60, Reward so far: -2034.65
#   Step 70, Reward so far: -2838.18
#   Step 80, Reward so far: -3596.56
#   Step 90, Reward so far: -4559.49
#   Step 100, Reward so far: -5440.35
# Episode 292/300 completed | Steps: 100 | Reward: -5440.35 | Epsilon: 0.05 | Time: 15.5s | Q-table size: 3809
#
# Starting Episode 293/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -371.17
#   Step 40, Reward so far: -814.92
#   Step 50, Reward so far: -1314.78
#   Step 60, Reward so far: -1883.09
#   Step 70, Reward so far: -2574.62
#   Step 80, Reward so far: -3243.67
#   Step 90, Reward so far: -4117.54
#   Step 100, Reward so far: -4982.93
# Episode 293/300 completed | Steps: 100 | Reward: -4982.93 | Epsilon: 0.05 | Time: 15.5s | Q-table size: 3809
#
# Starting Episode 294/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -405.13
#   Step 40, Reward so far: -884.68
#   Step 50, Reward so far: -1336.92
#   Step 60, Reward so far: -1917.14
#   Step 70, Reward so far: -2692.63
#   Step 80, Reward so far: -3415.45
#   Step 90, Reward so far: -4363.52
#   Step 100, Reward so far: -5339.45
# Episode 294/300 completed | Steps: 100 | Reward: -5339.45 | Epsilon: 0.05 | Time: 15.5s | Q-table size: 3809
#
# Starting Episode 295/300...
#   Step 10, Reward so far: -126.37
#   Step 20, Reward so far: -248.01
#   Step 30, Reward so far: -398.52
#   Step 40, Reward so far: -912.62
#   Step 50, Reward so far: -1424.87
#   Step 60, Reward so far: -2021.89
#   Step 70, Reward so far: -2748.26
#   Step 80, Reward so far: -3470.44
#   Step 90, Reward so far: -4310.08
#   Step 100, Reward so far: -5172.57
# Episode 295/300 completed | Steps: 100 | Reward: -5172.57 | Epsilon: 0.05 | Time: 15.5s | Q-table size: 3809
#
# Starting Episode 296/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -371.17
#   Step 40, Reward so far: -748.30
#   Step 50, Reward so far: -1347.61
#   Step 60, Reward so far: -1896.86
#   Step 70, Reward so far: -2548.27
#   Step 80, Reward so far: -3217.32
#   Step 90, Reward so far: -4091.18
#   Step 100, Reward so far: -4876.11
# Episode 296/300 completed | Steps: 100 | Reward: -4876.11 | Epsilon: 0.05 | Time: 15.6s | Q-table size: 3809
#
# Starting Episode 297/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -371.17
#   Step 40, Reward so far: -782.19
#   Step 50, Reward so far: -1303.13
#   Step 60, Reward so far: -1813.05
#   Step 70, Reward so far: -2425.26
#   Step 80, Reward so far: -3084.74
#   Step 90, Reward so far: -3929.39
#   Step 100, Reward so far: -4862.25
# Episode 297/300 completed | Steps: 100 | Reward: -4862.25 | Epsilon: 0.05 | Time: 15.6s | Q-table size: 3809
#
# Starting Episode 298/300...
#   Step 10, Reward so far: -91.14
#   Step 20, Reward so far: -149.05
#   Step 30, Reward so far: -351.13
#   Step 40, Reward so far: -825.72
#   Step 50, Reward so far: -1393.38
#   Step 60, Reward so far: -1924.35
#   Step 70, Reward so far: -2552.95
#   Step 80, Reward so far: -3239.99
#   Step 90, Reward so far: -4086.20
#   Step 100, Reward so far: -4940.43
# Episode 298/300 completed | Steps: 100 | Reward: -4940.43 | Epsilon: 0.05 | Time: 15.6s | Q-table size: 3809
#
# Starting Episode 299/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -220.67
#   Step 30, Reward so far: -587.57
#   Step 40, Reward so far: -1049.21
#   Step 50, Reward so far: -1572.07
#   Step 60, Reward so far: -2132.04
#   Step 70, Reward so far: -2791.97
#   Step 80, Reward so far: -3499.34
#   Step 90, Reward so far: -4400.40
#   Step 100, Reward so far: -5289.41
# Episode 299/300 completed | Steps: 100 | Reward: -5289.41 | Epsilon: 0.05 | Time: 15.6s | Q-table size: 3809
#
# Starting Episode 300/300...
#   Step 10, Reward so far: -99.03
#   Step 20, Reward so far: -202.12
#   Step 30, Reward so far: -346.93
#   Step 40, Reward so far: -703.26
#   Step 50, Reward so far: -1248.28
#   Step 60, Reward so far: -1794.01
#   Step 70, Reward so far: -2433.80
#   Step 80, Reward so far: -3102.85
#   Step 90, Reward so far: -3960.16
#   Step 100, Reward so far: -4720.97
# Episode 300/300 completed | Steps: 100 | Reward: -4720.97 | Epsilon: 0.05 | Time: 15.7s | Q-table size: 3809
# Model saved to enhanced_cloud_q_ep300.pkl
# Model saved to enhanced_cloud_q.pkl
# Final model saved to enhanced_cloud_q.pkl
# Best model was from episode 282 with reward -4605.77
# Starting evaluation phase with the best model...
# Initializing Q-table with guided values...
# Q-table initialization complete.
#
# Loading best model from enhanced_cloud_q_best.pkl for evaluation...
# Model loaded from enhanced_cloud_q_best.pkl
# Evaluating model for 200 steps...
# Starting evaluation for 200 steps...
#   Step 0/200...
#   Step 25/200...
#   Step 50/200...
#   Step 75/200...
# Evaluation complete. Total reward: -4986.50
# Starting rule-based evaluation for 200 steps...
#   Step 0/200...
#   Step 25/200...
#   Step 50/200...
#   Step 75/200...
# Rule-based evaluation complete. Total reward: -2018.28
# ==================================================
# EVALUATION METRICS
# ==================================================
#
# EC2 Metrics:
#   MAE: 5.2772
#   MSE: 41.8317
#   RMSE: 6.4677
#   SMAPE: 54.42%
#
# RDS Metrics:
#   MAE: 0.5347
#   MSE: 0.7525
#   RMSE: 0.8675
#   SMAPE: 14.72%
#
# ECS Metrics:
#   MAE: 7.9010
#   MSE: 109.3861
#   RMSE: 10.4588
#   SMAPE: 54.32%
#
# Overall Performance:
#   Q-Learning Average Reward: -49.8650
#   Rule-Based Average Reward: -20.1828
#   Reward Improvement: -29.6822
#
# ==================================================
#
# Final Q-Learning reward: -4986.50
# Final Rule-Based reward: -2018.28
# Improvement: -2968.22
#
# Training and evaluation complete!
# Best model was from episode 282 with reward -4605.77
